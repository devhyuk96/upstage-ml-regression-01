# %% [markdown]
# # **🏠 네이버 부동산 크롤링**
# > 더 자세한 정보가 나와있는 네이버 부동산 페이지를 크롤링하고자 한다.
# > 기본 데이터에 포함되어 있지 않은 최대층, 저층기준, 앞서 직방에서 나오지 않았던 방개수, 화장실개수, 세대수, 주차면적 등 여러 정보를 가져올 수 있다.
#
# ## Contents
# - Library Import
# - Data Load
# - Crawling of Naver real estate home page

# %% [markdown]
# ## 1. Library Import
# - 필요한 라이브러리를 불러옵니다.

# %%
# visualization
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumBarunGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 10, 'font.family': 'NanumBarunGothic'}) # 폰트 설정
plt.rc('font', family='NanumBarunGothic')
import seaborn as sns

# utils
import pandas as pd
import numpy as np
from tqdm import tqdm
import pickle
import warnings;warnings.filterwarnings('ignore')

# Model
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

import eli5
from eli5.sklearn import PermutationImportance

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
# Out:
# Failed to start the Kernel 'ss (Python 3.8.17)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. listen EFAULT: bad address in system call argument 192.168.0.13:9000

# %% [markdown]
# ## 2. Data Load

# %% [markdown]
# - 기존에 하던 데이터는 2007년 부터 이루어져 있기 때문에 절단해서 2017년부터 데이터에 포함하기로 결정

# %%
# 필요한 데이터를 load 하겠습니다. 경로는 환경에 맞게 지정해주면 됩니다.
add = pd.read_csv('../Data/address_to_latlon_complete.csv')
train = pd.read_csv('../Data/KOREAN_train4.csv')
test = pd.read_csv('../Data/KOREAN_test4.csv')

# %%
train = train[train['계약년월'] >= 201701]
train = train[train['target'] > 6111.11]
train[['연', '월']] = train['계약년월'].apply(lambda x: list(divmod(x, 100))).tolist()

# 정규표현식 패턴 생성
excluded_apts = ['AirPalace', 'SRvill', '경동팰리스힐', '대길B', '썬앤빌', '재선주택', '코원']

# go
pattern = '|'.join(excluded_apts)

# '열이름' 열에서 패턴이 있는지 확인하여 새로운 열 추가
train['is_아파트'] = np.where(train['아파트명'].str.contains(pattern), 1, 0)

train = train[train['is_아파트'] == 0]

train = train.drop(columns='is_아파트')

# %%
apart = train['아파트명'].unique()

# %%
train[['시', '구', '동']] = train['시군구'].str.split(expand = True)
test[['시', '구', '동']] = test['시군구'].str.split(expand = True)

# %%
dap = train[['동', '아파트명']].drop_duplicates(['아파트명']).reset_index()
dap2 = test[['동', '아파트명']].drop_duplicates(['아파트명']).reset_index()

# %%
dap['동아파트명'] = dap['동'] + ' ' + dap['아파트명']
dap2['동아파트명'] = dap2['동'] + ' ' + dap2['아파트명']

# %%
dap_merge = pd.concat([dap['동아파트명'], dap2['동아파트명']], axis = 0)

# %%
d = dap_merge.reset_index()['동아파트명']

# %%
d[d == "신당동 태원팰리스5차"]
# Out:
# 4608    신당동 태원팰리스5차
# Name: 동아파트명, dtype: object

# %%
apt_info = pd.read_csv('../Data/아파트정보.csv')
apt_area = pd.read_csv('../Data/아파트면적정보.csv')
apt_info = apt_info.iloc[:4577, :]
apt_info
# Out:
#             동아파트명                           세대수    저_최고층             총주차대수  \
# 0      개포동 개포6차우성                   270세대(총8개동)    5층/5층      270대(세대당 1대)
# 1      개포동 개포우성3차                   405세대(총5개동)  15층/15층   450대(세대당 1.11대)
# 2        개포동 개포자이                           NaN      NaN               NaN
# 3     개포동 개포주공1단지                           NaN      NaN               NaN
# 4     개포동 개포주공6단지                  1060세대(총9개동)  13층/15층   300대(세대당 0.28대)
# ...           ...                           ...      ...               ...
# 4572    신당동 약수하이츠  2282세대(기타임대 684세대 포함, 총19개동)   8층/20층  2091대(세대당 0.91대)
# 4573    신당동 인성아트빌                           NaN      NaN               NaN
# 4574      신당동 진달래                    19세대(총1개동)    4층/5층     21대(세대당 1.1대)
# 4575  신당동 청구e편한세상   895세대(영구임대 158세대 포함, 총15개동)   7층/15층  1010대(세대당 1.12대)
# 4576    신당동 청구파크뷰                    19세대(총1개동)    5층/7층    27대(세대당 1.42대)
#
#        용적률  건폐율        건설사
# 0     106%  21%    우성건설(주)
# 1     179%  15%    우성건설(주)
# 2      NaN  NaN        NaN
# 3      NaN  NaN        NaN
# 4        -    -     대한주택공사
# ...    ...  ...        ...
# 4572  255%  19%  동아건설산업(주)
# 4573   NaN  NaN        NaN
# 4574  257%  58%  이다종합건설(주)
# 4575  224%  23%       대림산업
# 4576  259%  58%  (주)이다종합건설
#
# [4577 rows x 7 columns]

# %% [markdown]
# ## 3. Crawling

# %%
ChromeDriverManager().install()
browser = webdriver.Chrome() # 우리가 컨트롤 할 수 있는 브라우저가 실행이된다.

# %%
browser.get('https://new.land.naver.com/search?ms=37.4848041,127.0730056,16&a=APT:ABYG:JGC:PRE&e=RETAIL')

# %%
# # 열 이름을 리스트로 지정
# column_names = ['동아파트명', '세대수', '저_최고층',
#                  '총주차대수', '용적률', '건폐율', '건설사']

# area_names = ['동아파트명', '공급전용면적', '방수욕실수',
#               '해당면적세대수', '현관구조']


# # 빈 데이터프레임 생성
# apt_info = pd.DataFrame(columns=column_names)
# apt_area = pd.DataFrame(columns=area_names)

# %%
# 없는 인덱스번호 저장
idx = []

for c, apt in enumerate(d[4609:6200]):

    # 체크
    comp = 0


    try:
        # 검색어 입력
        browser.find_element(By.ID, 'land_search').click()
        browser.find_element(By.ID, 'land_search').send_keys(Keys.CONTROL + "a")
        browser.find_element(By.ID, 'land_search').send_keys(apt)
        browser.find_element(By.ID, 'land_search').send_keys(Keys.ENTER)


        time.sleep(0.8)

        # 단지정보 클릭
        browser.find_element(By.CLASS_NAME, 'complex_link').click()

        comp = 1

        time.sleep(0.8)

        # 세대수
        a1 = browser.find_element(By.XPATH, '//*[@id="detailContents1"]/div[1]/table/tbody/tr[1]/td[1]').text

        # 저/최고층
        a2 = browser.find_element(By.XPATH, '//*[@id="detailContents1"]/div[1]/table/tbody/tr[1]/td[2]').text

        # 총 주차대수
        a3 = browser.find_element(By.XPATH, '//*[@id="detailContents1"]/div[1]/table/tbody/tr[2]/td[2]').text

        # 용적률
        a4 = browser.find_element(By.XPATH, '//*[@id="detailContents1"]/div[1]/table/tbody/tr[3]/td[1]').text
        
        # 건폐율
        a5 = browser.find_element(By.XPATH, '//*[@id="detailContents1"]/div[1]/table/tbody/tr[3]/td[2]').text

        # 건설사
        a6 = browser.find_element(By.XPATH, '//*[@id="detailContents1"]/div[1]/table/tbody/tr[4]/td[1]').text

        # 데이터프레임에 집어넣기
        apt_info.loc[len(apt_info), :] = [apt, a1, a2, a3, a4, a5, a6]

        try:
            i = 0
            while True:
                
                time.sleep(0.8)
                
                # 단지내 면적별 정보 클릭
                browser.find_element(By.XPATH, f'//*[@id="tab{i}"]').click()
                
                time.sleep(0.8)
                
                comp = 2

                # 공급/전용
                b1 = browser.find_element(By.XPATH, '//*[@id="tabpanel"]/table/tbody/tr[1]').text

                # 방수/욕실수
                b2 = browser.find_element(By.XPATH, '//*[@id="tabpanel"]/table/tbody/tr[2]').text
                        
                # 해당면적 세대수
                b3 = browser.find_element(By.XPATH, '//*[@id="tabpanel"]/table/tbody/tr[3]').text

                # 현관구조
                b4 = browser.find_element(By.XPATH, '//*[@id="tabpanel"]/table/tbody/tr[4]').text

                # 데이터에 집어넣기
                apt_area.loc[len(apt_area), :] = [apt, b1, b2, b3, b4]

                i += 1
        except:
            print(f"{apt}의 정보 담기를 {i}번까지 완료하였습니다.")
            pass

    except:
        if comp == 0:
            apt_info.loc[len(apt_info), :] = [apt, '', '', '', '', '', '']
            print(f"{apt}의 검색 결과가 하나가 아니거나 없습니다.")
            idx.append(c)
# Out:
# 신당동 프라임1의 정보 담기를 7번까지 완료하였습니다.
# 신당동 프라임2의 검색 결과가 하나가 아니거나 없습니다.
# 신당동 하이의 검색 결과가 하나가 아니거나 없습니다.
# 신당동 하이1의 검색 결과가 하나가 아니거나 없습니다.
# 예장동 예장동삼익의 정보 담기를 7번까지 완료하였습니다.
# 을지로5가 삼성파크빌의 검색 결과가 하나가 아니거나 없습니다.
# 인현동2가 인현상가의 정보 담기를 7번까지 완료하였습니다.
# 장충동1가 장충동라임카운티의 정보 담기를 6번까지 완료하였습니다.
# 장충동1가 장충레지던스의 정보 담기를 7번까지 완료하였습니다.
# 장충동2가 장충의 검색 결과가 하나가 아니거나 없습니다.
# 중림동 브라운스톤서울의 정보 담기를 7번까지 완료하였습니다.
# 중림동 삼성사이버빌리지의 정보 담기를 7번까지 완료하였습니다.
# 중림동 성요셉의 정보 담기를 7번까지 완료하였습니다.
# 충무로4가 진양상가의 정보 담기를 7번까지 완료하였습니다.
# 충무로5가 충무로엘크루메크로시티2차의 검색 결과가 하나가 아니거나 없습니다.
# 필동1가 하니맨션의 정보 담기를 5번까지 완료하였습니다.
# 황학동 DUO302의 검색 결과가 하나가 아니거나 없습니다.
# 황학동 골드캐슬Ⅲ의 검색 결과가 하나가 아니거나 없습니다.
# 황학동 그랜드힐오피스텔의 정보 담기를 6번까지 완료하였습니다.
# 황학동 황학아크로타워의 정보 담기를 7번까지 완료하였습니다.
# 회현동1가 남산롯데캐슬아이리스의 정보 담기를 1번까지 완료하였습니다.
# 회현동2가 쌍용남산플래티넘의 정보 담기를 6번까지 완료하였습니다.
# 흥인동 동대문와이즈캐슬의 검색 결과가 하나가 아니거나 없습니다.
# 흥인동 청계천두산위브더제니스의 검색 결과가 하나가 아니거나 없습니다.
# 망우동 예성그린캐슬의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 면목삼익의 정보 담기를 4번까지 완료하였습니다.
# 면목동 용마금호타운의 정보 담기를 1번까지 완료하였습니다.
# 면목동 용마동아의 정보 담기를 2번까지 완료하였습니다.
# 면목동 용마산금호어울림의 정보 담기를 5번까지 완료하였습니다.
# 면목동 용마산하늘채의 정보 담기를 5번까지 완료하였습니다.
# 면목동 용마한신의 검색 결과가 하나가 아니거나 없습니다.
# 묵동 묵동자이의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 상봉듀오트리스의 정보 담기를 5번까지 완료하였습니다.
# 황학동 신당블루카운티의 검색 결과가 하나가 아니거나 없습니다.
# 황학동 중구리버빌의 정보 담기를 7번까지 완료하였습니다.
# 황학동 청계리버팰리스A의 검색 결과가 하나가 아니거나 없습니다.
# 황학동 한양I-Class의 검색 결과가 하나가 아니거나 없습니다.
# 황학동 황학동코아루의 검색 결과가 하나가 아니거나 없습니다.
# 회현동1가 SK리더스뷰남산의 정보 담기를 7번까지 완료하였습니다.
# 회현동1가 이지-빌의 정보 담기를 7번까지 완료하였습니다.
# 흥인동 aaa의 검색 결과가 하나가 아니거나 없습니다.
# 흥인동 동대문솔하임의 검색 결과가 하나가 아니거나 없습니다.
# 흥인동 위더스하임의 검색 결과가 하나가 아니거나 없습니다.
# 망우동 EGSoulLeader의 정보 담기를 4번까지 완료하였습니다.
# 망우동 개나리의 정보 담기를 1번까지 완료하였습니다.
# 망우동 더하이어의 검색 결과가 하나가 아니거나 없습니다.
# 망우동 망우의 검색 결과가 하나가 아니거나 없습니다.
# 망우동 백림금호의 정보 담기를 3번까지 완료하였습니다.
# 망우동 산솔트윈의 정보 담기를 7번까지 완료하였습니다.
# 망우동 성도아트빌의 정보 담기를 5번까지 완료하였습니다.
# 망우동 예성그린캐슬2차의 정보 담기를 4번까지 완료하였습니다.
# 망우동 예아아트월드의 정보 담기를 1번까지 완료하였습니다.
# 망우동 예원캐슬의 검색 결과가 하나가 아니거나 없습니다.
# 망우동 용마프라자의 정보 담기를 1번까지 완료하였습니다.
# 망우동 주영의 정보 담기를 1번까지 완료하였습니다.
# 망우동 주영파크뷰의 정보 담기를 1번까지 완료하였습니다.
# 망우동 주함해븐의 정보 담기를 1번까지 완료하였습니다.
# 망우동 중랑숲리가의 정보 담기를 6번까지 완료하였습니다.
# 망우동 천보의 정보 담기를 7번까지 완료하였습니다.
# 망우동 한울네세창의 정보 담기를 5번까지 완료하였습니다.
# 망우동 한일써너스빌리젠시1단지의 검색 결과가 하나가 아니거나 없습니다.
# 망우동 한일써너스빌리젠시2단지의 검색 결과가 하나가 아니거나 없습니다.
# 망우동 해오름101동의 검색 결과가 하나가 아니거나 없습니다.
# 망우동 해오름102동의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 강호의 정보 담기를 7번까지 완료하였습니다.
# 면목동 건원베스트원의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 그린캐슬APT의 정보 담기를 7번까지 완료하였습니다.
# 면목동 늘푸른동아의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 대명미르테의 정보 담기를 4번까지 완료하였습니다.
# 면목동 대한의 정보 담기를 1번까지 완료하였습니다.
# 면목동 동서그랜드맨션의 정보 담기를 2번까지 완료하였습니다.
# 면목동 동성네스트빌101의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 동성네스트빌102의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 동진노블클래스의 정보 담기를 3번까지 완료하였습니다.
# 면목동 두산1의 정보 담기를 2번까지 완료하였습니다.
# 면목동 두산2의 정보 담기를 2번까지 완료하였습니다.
# 면목동 두산3의 정보 담기를 2번까지 완료하였습니다.
# 면목동 두산4의 정보 담기를 7번까지 완료하였습니다.
# 면목동 두산5의 정보 담기를 7번까지 완료하였습니다.
# 면목동 두산6의 정보 담기를 2번까지 완료하였습니다.
# 면목동 리치카운티의 정보 담기를 2번까지 완료하였습니다.
# 면목동 마젤란21의 정보 담기를 3번까지 완료하였습니다.
# 면목동 면목동2차미소지움의 정보 담기를 6번까지 완료하였습니다.
# 면목동 면목동금호어울림의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 면목삼호101의 정보 담기를 7번까지 완료하였습니다.
# 면목동 면목한신의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 미래한건의 정보 담기를 4번까지 완료하였습니다.
# 면목동 삼성제이드의 정보 담기를 7번까지 완료하였습니다.
# 면목동 성진리버타운의 정보 담기를 7번까지 완료하였습니다.
# 면목동 솔루테의 정보 담기를 5번까지 완료하였습니다.
# 면목동 신영의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 아람플러스의 정보 담기를 3번까지 완료하였습니다.
# 면목동 아이쉐르빌의 정보 담기를 2번까지 완료하였습니다.
# 면목동 온세솔내움의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 용마의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 용마한신2의 정보 담기를 3번까지 완료하였습니다.
# 면목동 일신강변의 정보 담기를 4번까지 완료하였습니다.
# 면목동 진성그린건설테라스의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 포인트의 정보 담기를 5번까지 완료하였습니다.
# 면목동 현대휴온의 정보 담기를 7번까지 완료하였습니다.
# 묵동 고덕골든빌의 검색 결과가 하나가 아니거나 없습니다.
# 묵동 늘봄의 정보 담기를 2번까지 완료하였습니다.
# 묵동 묵동포레시타의 정보 담기를 5번까지 완료하였습니다.
# 묵동 브라운스톤태릉의 정보 담기를 4번까지 완료하였습니다.
# 묵동 세방의 정보 담기를 3번까지 완료하였습니다.
# 묵동 신내의 검색 결과가 하나가 아니거나 없습니다.
# 묵동 신내대림의 정보 담기를 3번까지 완료하였습니다.
# 묵동 신내두산의 정보 담기를 3번까지 완료하였습니다.
# 묵동 신도의 검색 결과가 하나가 아니거나 없습니다.
# 묵동 신도2의 정보 담기를 4번까지 완료하였습니다.
# 묵동 신안1의 정보 담기를 3번까지 완료하였습니다.
# 묵동 신안2의 정보 담기를 2번까지 완료하였습니다.
# 묵동 신안3의 정보 담기를 3번까지 완료하였습니다.
# 묵동 월등스카이뷰의 정보 담기를 4번까지 완료하였습니다.
# 묵동 위더스빌의 정보 담기를 3번까지 완료하였습니다.
# 묵동 이편한세상화랑대의 검색 결과가 하나가 아니거나 없습니다.
# 묵동 태창네스트빌의 정보 담기를 7번까지 완료하였습니다.
# 묵동 하늘빛의 정보 담기를 3번까지 완료하였습니다.
# 묵동 한국의 정보 담기를 3번까지 완료하였습니다.
# 묵동 헤르만스테이트의 정보 담기를 3번까지 완료하였습니다.
# 상봉동 SG타워의 정보 담기를 2번까지 완료하였습니다.
# 상봉동 e-푸른가동의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 건영2차의 정보 담기를 4번까지 완료하였습니다.
# 상봉동 건영캐스빌의 정보 담기를 1번까지 완료하였습니다.
# 상봉동 금강산의 정보 담기를 4번까지 완료하였습니다.
# 상봉동 동일스카이시티101동의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 동일스카이시티102동의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 미랜드프래임빌의 정보 담기를 7번까지 완료하였습니다.
# 상봉동 엘지,쌍용의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 한일써너스빌의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 주함해븐타워의 정보 담기를 7번까지 완료하였습니다.
# 상봉동 태영데시앙1의 정보 담기를 5번까지 완료하였습니다.
# 상봉동 태영데시앙2의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 포시티의 정보 담기를 2번까지 완료하였습니다.
# 상봉동 풍산쉐르빌101동의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 프레미어스엠코의 정보 담기를 7번까지 완료하였습니다.
# 신내동 경원의 정보 담기를 2번까지 완료하였습니다.
# 신내동 다우훼밀리의 정보 담기를 3번까지 완료하였습니다.
# 신내동 대성유니트의 검색 결과가 하나가 아니거나 없습니다.
# 신내동 데시앙의 검색 결과가 하나가 아니거나 없습니다.
# 신내동 동광오뜨빌의 정보 담기를 3번까지 완료하였습니다.
# 신내동 동성1의 정보 담기를 7번까지 완료하였습니다.
# 신내동 동성3의 정보 담기를 7번까지 완료하였습니다.
# 신내동 동성5의 정보 담기를 1번까지 완료하였습니다.
# 신내동 동성7의 정보 담기를 3번까지 완료하였습니다.
# 신내동 동성타워프라자의 정보 담기를 4번까지 완료하였습니다.
# 신내동 신내 데시앙포레의 정보 담기를 5번까지 완료하였습니다.
# 신내동 신내11대명의 정보 담기를 3번까지 완료하였습니다.
# 신내동 신내6대주의 검색 결과가 하나가 아니거나 없습니다.
# 신내동 신내9진흥의 정보 담기를 4번까지 완료하였습니다.
# 신내동 신천빌리지의 정보 담기를 2번까지 완료하였습니다.
# 신내동 원당의 정보 담기를 1번까지 완료하였습니다.
# 신내동 조호그레이스의 정보 담기를 6번까지 완료하였습니다.
# 신내동 조호그레이스2의 정보 담기를 7번까지 완료하였습니다.
# 신내동 화성.두산의 정보 담기를 2번까지 완료하였습니다.
# 중화동 강오의 정보 담기를 7번까지 완료하였습니다.
# 중화동 동양엔파트2차의 정보 담기를 3번까지 완료하였습니다.
# 중화동 미영리치타운의 정보 담기를 2번까지 완료하였습니다.
# 중화동 미영리치타운103의 검색 결과가 하나가 아니거나 없습니다.
# 중화동 범양프레체의 검색 결과가 하나가 아니거나 없습니다.
# 중화동 연합파크빌의 검색 결과가 하나가 아니거나 없습니다.
# 중화동 중화동건영의 정보 담기를 5번까지 완료하였습니다.
# 중화동 청원다미소의 정보 담기를 3번까지 완료하였습니다.
# 중화동 태능에셈빌의 정보 담기를 5번까지 완료하였습니다.
# 중화동 현대휴앤미의 정보 담기를 7번까지 완료하였습니다.
# 개포동 개포더샵트리에의 정보 담기를 5번까지 완료하였습니다.
# 개포동 래미안블레스티지의 정보 담기를 7번까지 완료하였습니다.
# 개포동 개포래미안포레스트의 정보 담기를 7번까지 완료하였습니다.
# 개포동 개포자이프레지던스의 정보 담기를 7번까지 완료하였습니다.
# 개포동 디에이치아너힐즈의 정보 담기를 7번까지 완료하였습니다.
# 논현동 로체샤르캐슬의 정보 담기를 3번까지 완료하였습니다.
# 논현동 제이빌의 정보 담기를 7번까지 완료하였습니다.
# 도곡동 대명비발디의 정보 담기를 7번까지 완료하였습니다.
# 도곡동 상지리츠빌카일룸의 검색 결과가 하나가 아니거나 없습니다.
# 강일동 강동리버스트4단지의 정보 담기를 2번까지 완료하였습니다.
# 고덕동 고덕센트럴푸르지오의 검색 결과가 하나가 아니거나 없습니다.
# 명일동 래미안솔베뉴의 정보 담기를 7번까지 완료하였습니다.
# 상일동 고덕롯데캐슬베네루체의 정보 담기를 5번까지 완료하였습니다.
# 삼성동 그라나다의 정보 담기를 7번까지 완료하였습니다.
# 삼성동 래미안라클래시의 정보 담기를 6번까지 완료하였습니다.
# 삼성동 삼성오네뜨의 정보 담기를 3번까지 완료하였습니다.
# 삼성동 삼성월드타워의 정보 담기를 4번까지 완료하였습니다.
# 삼성동 아델하우스의 정보 담기를 6번까지 완료하였습니다.
# 신사동 유로미의 정보 담기를 7번까지 완료하였습니다.
# 신사동 토미의 정보 담기를 2번까지 완료하였습니다.
# 역삼동 강남센트럴아이파크의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 리츠빌의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 역삼엔스위트1의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 지석천평대의 정보 담기를 6번까지 완료하였습니다.
# 역삼동 프리마빌의 정보 담기를 7번까지 완료하였습니다.
# 일원동 디에이치자이개포의 정보 담기를 7번까지 완료하였습니다.
# 자곡동 엘에이치강남힐스테이트의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 아노스카운트빌라트의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 청담CJ빌리지의 정보 담기를 3번까지 완료하였습니다.
# 청담동 청담어퍼하우스의 정보 담기를 6번까지 완료하였습니다.
# 청담동 현대한강빌라의 정보 담기를 3번까지 완료하였습니다.
# 강일동 강동리버스트8단지의 정보 담기를 4번까지 완료하였습니다.
# 고덕동 고덕그라시움의 정보 담기를 7번까지 완료하였습니다.
# 길동 경지Arium의 검색 결과가 하나가 아니거나 없습니다.
# 길동 예건타워빌의 정보 담기를 6번까지 완료하였습니다.
# 길동 이편한세상강동에코포레의 정보 담기를 6번까지 완료하였습니다.
# 길동 효성노바의 정보 담기를 3번까지 완료하였습니다.
# 둔촌동 현대수린나의 정보 담기를 4번까지 완료하였습니다.
# 명일동 삼보힐의 정보 담기를 3번까지 완료하였습니다.
# 명일동 우성101동의 검색 결과가 하나가 아니거나 없습니다.
# 상일동 고덕센트럴IPARK의 검색 결과가 하나가 아니거나 없습니다.
# 상일동 고덕아르테온의 정보 담기를 7번까지 완료하였습니다.
# 마곡동 마곡엠밸리9단지의 정보 담기를 7번까지 완료하였습니다.
# 상일동 고덕자이의 정보 담기를 7번까지 완료하였습니다.
# 성내동 강동다온채의 정보 담기를 7번까지 완료하였습니다.
# 성내동 집앤사비디의 정보 담기를 7번까지 완료하였습니다.
# 성내동 한양립스의 검색 결과가 하나가 아니거나 없습니다.
# 암사동 경지리버캐슬의 정보 담기를 5번까지 완료하였습니다.
# 암사동 힐스테이트 강동 리버뷰의 정보 담기를 5번까지 완료하였습니다.
# 천호동 미사아름채의 검색 결과가 하나가 아니거나 없습니다.
# 천호동 아스하임의 검색 결과가 하나가 아니거나 없습니다.
# 천호동 천호2차이룸의 정보 담기를 4번까지 완료하였습니다.
# 미아동 꿈의숲한신더휴의 정보 담기를 7번까지 완료하였습니다.
# 미아동 꿈의숲해링턴플레이스의 정보 담기를 7번까지 완료하였습니다.
# 미아동 젬스톤타운의 정보 담기를 1번까지 완료하였습니다.
# 미아동 포르투나의 검색 결과가 하나가 아니거나 없습니다.
# 번동 빌드아르떼APT의 검색 결과가 하나가 아니거나 없습니다.
# 수유동 진명의 정보 담기를 5번까지 완료하였습니다.
# 수유동 칸타빌수유팰리스의 정보 담기를 7번까지 완료하였습니다.
# 수유동 한원힐트리움수유의 검색 결과가 하나가 아니거나 없습니다.
# 가양동 마곡보타닉의 검색 결과가 하나가 아니거나 없습니다.
# 내발산동 수명산태송팰리채의 정보 담기를 4번까지 완료하였습니다.
# 내발산동 신세계3차101동의 정보 담기를 3번까지 완료하였습니다.
# 내발산동 우장산신일해피트리의 정보 담기를 7번까지 완료하였습니다.
# 내발산동 우장산한울에이치밸리움의 정보 담기를 6번까지 완료하였습니다.
# 내발산동 이너스101동의 검색 결과가 하나가 아니거나 없습니다.
# 등촌동 등촌퀸즈포디엄삼익의 정보 담기를 4번까지 완료하였습니다.
# 등촌동 등촌파밀리에더클래식201동의 검색 결과가 하나가 아니거나 없습니다.
# 등촌동 마곡루나플라체의 정보 담기를 2번까지 완료하였습니다.
# 봉천동 e편한세상서울대입구1단지의 검색 결과가 하나가 아니거나 없습니다.
# 방화동 다우하임더프라임의 정보 담기를 7번까지 완료하였습니다.
# 방화동 마곡우촌의 정보 담기를 5번까지 완료하였습니다.
# 방화동 신라힐의 정보 담기를 3번까지 완료하였습니다.
# 방화동 신마곡벽산블루밍의 정보 담기를 7번까지 완료하였습니다.
# 염창동 e편한세상염창의 정보 담기를 7번까지 완료하였습니다.
# 염창동 한울밸리움의 정보 담기를 7번까지 완료하였습니다.
# 화곡동 SPACE의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 강동의 정보 담기를 1번까지 완료하였습니다.
# 화곡동 강서크라운팰리스의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 굿이모션의 정보 담기를 6번까지 완료하였습니다.
# 화곡동 궁전B동의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 꿈동산의 정보 담기를 5번까지 완료하였습니다.
# 화곡동 루체비스타의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 산내들의 정보 담기를 3번까지 완료하였습니다.
# 화곡동 스위트드림의 정보 담기를 5번까지 완료하였습니다.
# 화곡동 에스타워의 정보 담기를 3번까지 완료하였습니다.
# 화곡동 오화의 정보 담기를 3번까지 완료하였습니다.
# 화곡동 요산페어뷰의 정보 담기를 2번까지 완료하였습니다.
# 화곡동 우장산숲아이파크의 정보 담기를 7번까지 완료하였습니다.
# 화곡동 유원펠리체의 정보 담기를 1번까지 완료하였습니다.
# 화곡동 천우네오젠9차의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 풍원팰리스의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 한울에이치밸리움A동의 정보 담기를 7번까지 완료하였습니다.
# 화곡동 한울에이치밸리움B동의 정보 담기를 7번까지 완료하였습니다.
# 화곡동 혜성오피의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 황제팰리체의 검색 결과가 하나가 아니거나 없습니다.
# 남현동 네스코수피아의 검색 결과가 하나가 아니거나 없습니다.
# 봉천동 e편한세상서울대입구2단지의 검색 결과가 하나가 아니거나 없습니다.
# 봉천동 e편한세상서울대입구2차의 정보 담기를 6번까지 완료하였습니다.
# 봉천동 새진7차의 검색 결과가 하나가 아니거나 없습니다.
# 봉천동 에메랄드104동의 검색 결과가 하나가 아니거나 없습니다.
# 신림동 G밸리마인드의 검색 결과가 하나가 아니거나 없습니다.
# 신림동 가야위드안의 정보 담기를 7번까지 완료하였습니다.
# 신림동 산장그린의 정보 담기를 1번까지 완료하였습니다.
# 신림동 앰팰리스의 정보 담기를 2번까지 완료하였습니다.
# 신림동 위드비엠3의 검색 결과가 하나가 아니거나 없습니다.
# 신림동 힐스테이트뉴포레의 정보 담기를 4번까지 완료하였습니다.
# 광장동 광장동현대Ⅰ빌라트의 검색 결과가 하나가 아니거나 없습니다.
# 구의동 e편한세상광진그랜드파크의 정보 담기를 6번까지 완료하였습니다.
# 구의동 래미안파크스위트의 정보 담기를 7번까지 완료하였습니다.
# 군자동 에피소드1의 검색 결과가 하나가 아니거나 없습니다.
# 자양동 자양동명진센트라임의 검색 결과가 하나가 아니거나 없습니다.
# 자양동 자양호반써밋의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 e편한세상독산더타워의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 금천롯데캐슬골드파크3차의 정보 담기를 7번까지 완료하였습니다.
# 공릉동 태릉해링턴플레이스의 정보 담기를 7번까지 완료하였습니다.
# 자양동 테라팰리스건대2차의 검색 결과가 하나가 아니거나 없습니다.
# 중곡동 에이탑의 정보 담기를 5번까지 완료하였습니다.
# 화양동 광진스위트엠의 정보 담기를 4번까지 완료하였습니다.
# 화양동 더메종건대의 정보 담기를 5번까지 완료하였습니다.
# 고척동 개봉청구의 정보 담기를 2번까지 완료하였습니다.
# 구로동 우진빌라1차A의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 경원주택5동의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 두암호은리버빌의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 M센트럴뷰의 정보 담기를 6번까지 완료하였습니다.
# 구로동 구로오네뜨시티의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 다원그린빌의 정보 담기를 2번까지 완료하였습니다.
# 구로동 대신빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 마인드에코프라움의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 번영빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 송림빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 청우아트빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 황산의 검색 결과가 하나가 아니거나 없습니다.
# 신도림동 신도림 아르디에의 정보 담기를 7번까지 완료하였습니다.
# 오류동 오류동삼전솔하임의 검색 결과가 하나가 아니거나 없습니다.
# 오류동 우창굿모닝의 정보 담기를 3번까지 완료하였습니다.
# 오류동 한백힐의 정보 담기를 2번까지 완료하였습니다.
# 항동 우남퍼스트빌더센트럴의 정보 담기를 7번까지 완료하였습니다.
# 항동 하버라인2단지의 정보 담기를 6번까지 완료하였습니다.
# 항동 하버라인3단지의 정보 담기를 7번까지 완료하였습니다.
# 항동 하버라인4단지의 정보 담기를 2번까지 완료하였습니다.
# 항동 한양수자인에듀힐즈의 정보 담기를 6번까지 완료하였습니다.
# 항동 항동중흥에스클래스베르데카운티의 정보 담기를 4번까지 완료하였습니다.
# 가산동 G밸리페트라힐스의 정보 담기를 2번까지 완료하였습니다.
# 가산동 가산지웰에스테이트의 검색 결과가 하나가 아니거나 없습니다.
# 가산동 가산지웰에스테이트2차의 검색 결과가 하나가 아니거나 없습니다.
# 가산동 가산피어니빌의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 금천롯데캐슬골드파크2차201동202동의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 독산오르페움타워의 정보 담기를 3번까지 완료하였습니다.
# 독산동 동은4차의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 명도힐스티지의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 세심의 정보 담기를 7번까지 완료하였습니다.
# 독산동 아셈그린힐의 정보 담기를 2번까지 완료하였습니다.
# 독산동 아이유하임의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 푸른터의 정보 담기를 2번까지 완료하였습니다.
# 시흥동 거상장미의 정보 담기를 4번까지 완료하였습니다.
# 시흥동 거상홈타운801동의 검색 결과가 하나가 아니거나 없습니다.
# 시흥동 백운한비치5의 정보 담기를 7번까지 완료하였습니다.
# 시흥동 애시안의 정보 담기를 4번까지 완료하였습니다.
# 시흥동 예일의 정보 담기를 3번까지 완료하였습니다.
# 공릉동 미라쉘의 정보 담기를 3번까지 완료하였습니다.
# 공릉동 임성의 정보 담기를 5번까지 완료하였습니다.
# 공릉동 테라파크뷰의 정보 담기를 7번까지 완료하였습니다.
# 월계동 월계센트럴아이파크의 정보 담기를 5번까지 완료하였습니다.
# 중계동 중계3벽산의 정보 담기를 3번까지 완료하였습니다.
# 상계동 상계1차중앙하이츠의 정보 담기를 3번까지 완료하였습니다.
# 상계동 수락산벨리체의 정보 담기를 2번까지 완료하였습니다.
# 상계동 중계센트럴파크의 정보 담기를 6번까지 완료하였습니다.
# 공릉동 화랑대디오베이션의 정보 담기를 1번까지 완료하였습니다.
# 상계동 노원센트럴푸르지오의 정보 담기를 7번까지 완료하였습니다.
# 상계동 포레나노원의 정보 담기를 7번까지 완료하였습니다.
# 중계동 중앙하이츠아쿠아의 정보 담기를 4번까지 완료하였습니다.
# 도봉동 신도봉의 정보 담기를 6번까지 완료하였습니다.
# 쌍문동 브라운스톤쌍문의 정보 담기를 7번까지 완료하였습니다.
# 답십리동 답십리파크자이의 정보 담기를 7번까지 완료하였습니다.
# 장안동 동대문더퍼스트데시앙의 정보 담기를 6번까지 완료하였습니다.
# 휘경동 휘경SK뷰의 정보 담기를 7번까지 완료하였습니다.
# 방학동 방학지음재힐스의 정보 담기를 6번까지 완료하였습니다.
# 방학동 송학휴스테이의 정보 담기를 7번까지 완료하였습니다.
# 휘경동 브라운스톤휘경의 정보 담기를 6번까지 완료하였습니다.
# 방학동 성진파크뷰의 정보 담기를 3번까지 완료하였습니다.
# 쌍문동 신건영주택A의 검색 결과가 하나가 아니거나 없습니다.
# 쌍문동 하루방의 검색 결과가 하나가 아니거나 없습니다.
# 창동 스마트트라움의 정보 담기를 1번까지 완료하였습니다.
# 답십리동 답십리엘림퍼스트의 정보 담기를 3번까지 완료하였습니다.
# 답십리동 보광타워의 검색 결과가 하나가 아니거나 없습니다.
# 답십리동 한원힐트리움의 정보 담기를 7번까지 완료하였습니다.
# 용두동 래미안엘리니티의 정보 담기를 7번까지 완료하였습니다.
# 용두동 이편한세상청계센트럴포레의 검색 결과가 하나가 아니거나 없습니다.
# 용두동 청계한양아이클래스의 검색 결과가 하나가 아니거나 없습니다.
# 용두동 청재제일타운의 정보 담기를 7번까지 완료하였습니다.
# 이문동 민족통일MJ캠퍼스외대3차의 정보 담기를 6번까지 완료하였습니다.
# 이문동 세진빌딩의 검색 결과가 하나가 아니거나 없습니다.
# 이문동 이문스카이뷰의 검색 결과가 하나가 아니거나 없습니다.
# 이문동 주성아우라의 검색 결과가 하나가 아니거나 없습니다.
# 이문동 투니온의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 공감대5차의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 글로벌팰리스의 검색 결과가 하나가 아니거나 없습니다.
# 전농동 동대문롯데캐슬노블레스의 정보 담기를 4번까지 완료하였습니다.
# 제기동 동성네스트빌의 정보 담기를 7번까지 완료하였습니다.
# 회기동 동일스카이시티3차의 검색 결과가 하나가 아니거나 없습니다.
# 회기동 민족통일MJ캠퍼스경희대2차의 정보 담기를 4번까지 완료하였습니다.
# 휘경동 캠퍼스드림오피스텔의 정보 담기를 1번까지 완료하였습니다.
# 사당동 사당롯데캐슬골든포레의 정보 담기를 7번까지 완료하였습니다.
# 사당동 이수푸르지오더프레티움의 정보 담기를 7번까지 완료하였습니다.
# 상도동 상도역롯데캐슬파크엘의 정보 담기를 7번까지 완료하였습니다.
# 염리동 마포프레스티지자이의 정보 담기를 7번까지 완료하였습니다.
# 휘경동 휘경해모로프레스티지의 정보 담기를 5번까지 완료하였습니다.
# 대방동 드림빌라트의 정보 담기를 6번까지 완료하였습니다.
# 상도동 e편한세상상도노빌리티의 정보 담기를 7번까지 완료하였습니다.
# 상도동 상도고구의 정보 담기를 7번까지 완료하였습니다.
# 신대방동 보라매자이더포레스트의 정보 담기를 7번까지 완료하였습니다.
# 흑석동 롯데캐슬에듀포레의 정보 담기를 6번까지 완료하였습니다.
# 흑석동 아크로리버하임의 정보 담기를 7번까지 완료하였습니다.
# 공덕동 공덕SK리더스뷰의 정보 담기를 6번까지 완료하였습니다.
# 공덕동 솔리스타의 검색 결과가 하나가 아니거나 없습니다.
# 노고산동 신촌그랑자이의 검색 결과가 하나가 아니거나 없습니다.
# 망원동 뉴성신의 정보 담기를 7번까지 완료하였습니다.
# 망원동 마포한강아이파크의 정보 담기를 7번까지 완료하였습니다.
# 망원동 마포한강제이스카이의 정보 담기를 7번까지 완료하였습니다.
# 망원동 솔루체2차의 정보 담기를 7번까지 완료하였습니다.
# 망원동 스카이캐슬의 정보 담기를 7번까지 완료하였습니다.
# 상수동 상수동월드메르디앙의 정보 담기를 2번까지 완료하였습니다.
# 상암동 예인하우스의 정보 담기를 7번까지 완료하였습니다.
# 성산동 라인성서의 정보 담기를 7번까지 완료하였습니다.
# 성산동 성일빌딩의 검색 결과가 하나가 아니거나 없습니다.
# 신수동 신촌숲아이파크의 정보 담기를 6번까지 완료하였습니다.
# 염리동 마포자이더센트리지의 정보 담기를 7번까지 완료하였습니다.
# 남가좌동 DMC에코자이의 정보 담기를 7번까지 완료하였습니다.
# 북아현동 힐스테이트신촌의 정보 담기를 7번까지 완료하였습니다.
# 홍은동 북한산두산위브2차의 정보 담기를 3번까지 완료하였습니다.
# 홍제동 서대문푸르지오센트럴파크의 정보 담기를 7번까지 완료하였습니다.
# 반포동 반포써밋의 정보 담기를 7번까지 완료하였습니다.
# 방배동 방배그랑자이의 정보 담기를 7번까지 완료하였습니다.
# 서초동 서초그랑자이의 정보 담기를 7번까지 완료하였습니다.
# 반포동 디에이치반포라클라스의 정보 담기를 7번까지 완료하였습니다.
# 역삼동 대우디오빌플러스의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 역삼2차아이파크의 검색 결과가 하나가 아니거나 없습니다.
# 천호동 대우한강베네시티의 검색 결과가 하나가 아니거나 없습니다.
# 번동 번동금호어울림의 정보 담기를 4번까지 완료하였습니다.
# 마곡동 마곡엠밸리8단지의 정보 담기를 6번까지 완료하였습니다.
# 방화동 치현마을동일스위트리버의 검색 결과가 하나가 아니거나 없습니다.
# 마곡동 마곡엠밸리12단지의 정보 담기를 4번까지 완료하였습니다.
# 마곡동 마곡엠밸리6단지의 정보 담기를 6번까지 완료하였습니다.
# 염창동 삼정그린코아의 정보 담기를 6번까지 완료하였습니다.
# 봉천동 관악월드메르디앙의 정보 담기를 3번까지 완료하였습니다.
# 자양동 한솔리베르의 정보 담기를 5번까지 완료하였습니다.
# 개봉동 청실의 정보 담기를 2번까지 완료하였습니다.
# 자양동 자양7차현대홈타운의 정보 담기를 7번까지 완료하였습니다.
# 시흥동 시흥베르빌의 정보 담기를 5번까지 완료하였습니다.
# 월계동 월계흥화브라운빌의 정보 담기를 5번까지 완료하였습니다.
# 쌍문동 북한산코오롱하늘채의 정보 담기를 5번까지 완료하였습니다.
# 창동 북한산한신휴플러스의 정보 담기를 3번까지 완료하였습니다.
# 창동 창동한승미메이드의 정보 담기를 3번까지 완료하였습니다.
# 휘경동 휘경센트레빌의 정보 담기를 5번까지 완료하였습니다.
# 본동 유원강변의 정보 담기를 5번까지 완료하였습니다.
# 사당동 래미안로이파크의 정보 담기를 7번까지 완료하였습니다.
# 상도동 상도효성해링턴플레이스의 정보 담기를 5번까지 완료하였습니다.
# 신대방동 현진에버빌의 정보 담기를 2번까지 완료하였습니다.
# 공덕동 공덕현대의 검색 결과가 하나가 아니거나 없습니다.
# 상암동 상암월드컵파크6단지의 정보 담기를 2번까지 완료하였습니다.
# 남가좌동 DMC센트레빌의 정보 담기를 6번까지 완료하였습니다.
# 북가좌동 DMC휴먼빌의 정보 담기를 4번까지 완료하였습니다.
# 서초동 서초3차e편한세상의 정보 담기를 2번까지 완료하였습니다.
# 서초동 서초삼성래미안의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 서초한빛삼성의 정보 담기를 4번까지 완료하였습니다.
# 신원동 서초포레스타6단지의 정보 담기를 6번까지 완료하였습니다.
# 돈암동 돈암현대의 검색 결과가 하나가 아니거나 없습니다.
# 장지동 송파파인타운7단지의 정보 담기를 3번까지 완료하였습니다.
# 장지동 송파파인타운9단지의 정보 담기를 3번까지 완료하였습니다.
# 영등포동7가 아크로타워스퀘어의 정보 담기를 7번까지 완료하였습니다.
# 구산동 갈현현대의 정보 담기를 4번까지 완료하였습니다.
# 숭인동 종로센트레빌의 정보 담기를 3번까지 완료하였습니다.
# 묵정동 묵정의 검색 결과가 하나가 아니거나 없습니다.
# 신내동 신내우디안1단지의 정보 담기를 6번까지 완료하였습니다.
# 일원동 디에이치포레센트의 정보 담기를 5번까지 완료하였습니다.
# 등촌동 가양역두산위브의 정보 담기를 6번까지 완료하였습니다.
# 염리동 우리파크의 정보 담기를 7번까지 완료하였습니다.
# 창전동 마포웨스트리버태영데시앙의 정보 담기를 7번까지 완료하였습니다.
# 남가좌동 DMC센트럴아이파크의 정보 담기를 7번까지 완료하였습니다.
# 남가좌동 래미안루센티아의 정보 담기를 7번까지 완료하였습니다.
# 대현동 이대경우타운의 정보 담기를 4번까지 완료하였습니다.
# 대현동 파라타워의 검색 결과가 하나가 아니거나 없습니다.
# 북아현동 문영센스빌의 정보 담기를 7번까지 완료하였습니다.
# 연희동 경향빌라트의 정보 담기를 3번까지 완료하였습니다.
# 연희동 드리밍의 검색 결과가 하나가 아니거나 없습니다.
# 연희동 연희아트빌의 정보 담기를 7번까지 완료하였습니다.
# 연희동 연희파크푸르지오의 정보 담기를 6번까지 완료하였습니다.
# 연희동 한인트윈빌의 정보 담기를 1번까지 완료하였습니다.
# 홍은동 HDX휴팰리스의 정보 담기를 3번까지 완료하였습니다.
# 홍은동 동평늘푸른의 정보 담기를 5번까지 완료하였습니다.
# 홍은동 북한산두산위브의 검색 결과가 하나가 아니거나 없습니다.
# 홍은동 서강주상복합의 검색 결과가 하나가 아니거나 없습니다.
# 홍은동 힐스테이트홍은포레스트의 정보 담기를 5번까지 완료하였습니다.
# 홍제동 경일의 정보 담기를 6번까지 완료하였습니다.
# 홍제동 동일2차의 정보 담기를 7번까지 완료하였습니다.
# 홍제동 홍제센트럴IPARK의 정보 담기를 6번까지 완료하였습니다.
# 홍제동 홍제역해링턴플레이스의 정보 담기를 7번까지 완료하였습니다.
# 반포동 더샵반포리버파크의 정보 담기를 7번까지 완료하였습니다.
# 반포동 래미안원베일리의 정보 담기를 7번까지 완료하였습니다.
# 반포동 레베빌의 정보 담기를 4번까지 완료하였습니다.
# 반포동 반포두산힐스빌의 정보 담기를 5번까지 완료하였습니다.
# 반포동 반포센트레빌아스테리움의 정보 담기를 6번까지 완료하였습니다.
# 방배동 방배 서리풀 그랑블의 정보 담기를 6번까지 완료하였습니다.
# 방배동 방배마에스트로의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 방배아트e편한세상105의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 방배아트자이의 정보 담기를 7번까지 완료하였습니다.
# 방배동 방배중앙센트레빌의 정보 담기를 5번까지 완료하였습니다.
# 방배동 힐스나인빌리지의 정보 담기를 7번까지 완료하였습니다.
# 서초동 DK밸리뷰시티의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 래미안 리더스원의 정보 담기를 7번까지 완료하였습니다.
# 서초동 로얄파크에이의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 루컴즈힐서리풀의 정보 담기를 6번까지 완료하였습니다.
# 서초동 서초네스피아B의 정보 담기를 4번까지 완료하였습니다.
# 서초동 서초노블레스의 검색 결과가 하나가 아니거나 없습니다.
# 잠원동 반포센트럴자이의 정보 담기를 7번까지 완료하였습니다.
# 금호동4가 힐스테이트서울숲리버의 정보 담기를 7번까지 완료하였습니다.
# 행당동 서울숲리버뷰자이의 정보 담기를 6번까지 완료하였습니다.
# 서초동 서초센트럴IPARK의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 서초아트빌의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 지에스타워의 정보 담기를 6번까지 완료하였습니다.
# 서초동 트라움하우스3의 정보 담기를 4번까지 완료하였습니다.
# 우면동 엘에이치서초4단지의 검색 결과가 하나가 아니거나 없습니다.
# 잠원동 래미안신반포리오센트의 정보 담기를 7번까지 완료하였습니다.
# 잠원동 반포르엘의 검색 결과가 하나가 아니거나 없습니다.
# 상왕십리동 센트럴큐브의 검색 결과가 하나가 아니거나 없습니다.
# 성수동1가 아크로서울포레스트의 정보 담기를 6번까지 완료하였습니다.
# 하왕십리동 왕십리지음재의 정보 담기를 2번까지 완료하였습니다.
# 길음동 래미안길음센터피스의 정보 담기를 7번까지 완료하였습니다.
# 장위동 장위지웰에스테이트의 정보 담기를 7번까지 완료하였습니다.
# 가락동 헬리오시티의 정보 담기를 7번까지 완료하였습니다.
# 거여동 송파위례리슈빌의 정보 담기를 7번까지 완료하였습니다.
# 장위동 꿈의숲아이파크의 정보 담기를 6번까지 완료하였습니다.
# 길음동 롯데캐슬골든힐스의 정보 담기를 7번까지 완료하였습니다.
# 길음동 롯데캐슬클라시아의 정보 담기를 7번까지 완료하였습니다.
# 동소문동7가 샤인힐의 정보 담기를 4번까지 완료하였습니다.
# 석관동 래미안아트리치의 정보 담기를 7번까지 완료하였습니다.
# 장위동 라인캐슬의 검색 결과가 하나가 아니거나 없습니다.
# 장위동 래미안장위퍼스트하이의 정보 담기를 6번까지 완료하였습니다.
# 장위동 래미안포레카운티의 정보 담기를 4번까지 완료하였습니다.
# 장위동 석계역한일노벨리아시티의 검색 결과가 하나가 아니거나 없습니다.
# 정릉동 갤럭시더정릉의 검색 결과가 하나가 아니거나 없습니다.
# 종암동 해가온팰리스의 정보 담기를 4번까지 완료하였습니다.
# 가락동 대련의 정보 담기를 3번까지 완료하였습니다.
# 가락동 우민-늘푸른의 정보 담기를 1번까지 완료하였습니다.
# 가락동 현진타워의 검색 결과가 하나가 아니거나 없습니다.
# 거여동 e편한세상송파파크센트럴의 정보 담기를 7번까지 완료하였습니다.
# 거여동 송파레이크파크호반써밋Ⅱ의 검색 결과가 하나가 아니거나 없습니다.
# 거여동 송파시그니처롯데캐슬의 정보 담기를 6번까지 완료하였습니다.
# 문정동 동궁리치웰문정의 검색 결과가 하나가 아니거나 없습니다.
# 풍납동 잠실올림픽공원아이파크의 정보 담기를 7번까지 완료하였습니다.
# 방이동 더원센트럴의 검색 결과가 하나가 아니거나 없습니다.
# 방이동 올림픽타워1의 검색 결과가 하나가 아니거나 없습니다.
# 삼전동 경덕의 검색 결과가 하나가 아니거나 없습니다.
# 송파동 현대레이크빌1의 검색 결과가 하나가 아니거나 없습니다.
# 오금동 송파두산위브의 정보 담기를 2번까지 완료하였습니다.
# 오금동 에스아이팰리스송파올림픽공원의 정보 담기를 4번까지 완료하였습니다.
# 오금동 오금그랑밸리의 검색 결과가 하나가 아니거나 없습니다.
# 잠실동 NS파인트리의 검색 결과가 하나가 아니거나 없습니다.
# 풍납동 칼라의 정보 담기를 7번까지 완료하였습니다.
# 목동 동도의 검색 결과가 하나가 아니거나 없습니다.
# 목동 목동롯데캐슬마에스트로의 정보 담기를 6번까지 완료하였습니다.
# 목동 목동벨로스주상복합의 정보 담기를 2번까지 완료하였습니다.
# 목동 목동에버하임의 정보 담기를 4번까지 완료하였습니다.
# 당산동5가 당산센트럴아이파크의 정보 담기를 7번까지 완료하였습니다.
# 대림동 영등포자이르네의 정보 담기를 4번까지 완료하였습니다.
# 문래동6가 e편한세상 문래 에듀플라츠의 정보 담기를 4번까지 완료하였습니다.
# 신길동 더샵파크프레스티지의 정보 담기를 6번까지 완료하였습니다.
# 신길동 신길센트럴자이의 정보 담기를 7번까지 완료하였습니다.
# 신길동 신길파크자이의 정보 담기를 7번까지 완료하였습니다.
# 신길동 힐스테이트클래시안의 정보 담기를 7번까지 완료하였습니다.
# 신정동 목동파크자이의 정보 담기를 5번까지 완료하였습니다.
# 신길동 신길센트럴아이파크의 정보 담기를 6번까지 완료하였습니다.
# 신월동 목동센트럴아이파크위브1단지의 검색 결과가 하나가 아니거나 없습니다.
# 신월동 목동센트럴아이파크위브2단지의 검색 결과가 하나가 아니거나 없습니다.
# 신월동 목동센트럴아이파크위브3단지의 검색 결과가 하나가 아니거나 없습니다.
# 신월동 목동센트럴아이파크위브4단지의 검색 결과가 하나가 아니거나 없습니다.
# 신월동 빛여울의 정보 담기를 3번까지 완료하였습니다.
# 신월동 오투힐의 정보 담기를 7번까지 완료하였습니다.
# 신월동 탑건위너스빌의 검색 결과가 하나가 아니거나 없습니다.
# 신월동 훼미리주상복합의 검색 결과가 하나가 아니거나 없습니다.
# 신정동 동국화이트빌B동의 검색 결과가 하나가 아니거나 없습니다.
# 신정동 래미안목동아델리체의 정보 담기를 7번까지 완료하였습니다.
# 신정동 제이클래스목동주상복합의 검색 결과가 하나가 아니거나 없습니다.
# 당산동 리버뷰의 검색 결과가 하나가 아니거나 없습니다.
# 대림동 G밸리소홈의 검색 결과가 하나가 아니거나 없습니다.
# 대림동 e편한세상영등포아델포레의 정보 담기를 6번까지 완료하였습니다.
# 대림동 다청림2동의 검색 결과가 하나가 아니거나 없습니다.
# 대림동 삼화에코빌1차의 검색 결과가 하나가 아니거나 없습니다.
# 신길동 보라매에스케이뷰의 정보 담기를 7번까지 완료하였습니다.
# 양평동1가 어반힐의 검색 결과가 하나가 아니거나 없습니다.
# 양평동1가 영등포중흥에스클래스의 검색 결과가 하나가 아니거나 없습니다.
# 양평동3가 양평역미소지움의 정보 담기를 4번까지 완료하였습니다.
# 양평동6가 리츠뷰의 정보 담기를 3번까지 완료하였습니다.
# 영등포동7가 포레나영등포센트럴의 검색 결과가 하나가 아니거나 없습니다.
# 효창동 용산롯데캐슬센터포레의 정보 담기를 7번까지 완료하였습니다.
# 녹번동 래미안베라힐즈의 정보 담기를 6번까지 완료하였습니다.
# 녹번동 힐스테이트녹번의 정보 담기를 7번까지 완료하였습니다.
# 불광동 불광롯데캐슬의 정보 담기를 6번까지 완료하였습니다.
# 신사동 응암역효성해링턴플레이스의 정보 담기를 7번까지 완료하였습니다.
# 응암동 녹번역e편한세상캐슬의 정보 담기를 7번까지 완료하였습니다.
# 응암동 백련산파크자이의 정보 담기를 7번까지 완료하였습니다.
# 응암동 힐스테이트녹번역의 정보 담기를 7번까지 완료하였습니다.
# 증산동 DMC센트럴자이의 정보 담기를 7번까지 완료하였습니다.
# 진관동 은평스카이뷰자이의 정보 담기를 2번까지 완료하였습니다.
# 수색동 DMC롯데캐슬더퍼스트의 정보 담기를 7번까지 완료하였습니다.
# 영등포동 라르파크의 정보 담기를 6번까지 완료하였습니다.
# 영등포동1가 여의도더리브스타일의 검색 결과가 하나가 아니거나 없습니다.
# 영등포동1가 여의도이튼브라운의 정보 담기를 5번까지 완료하였습니다.
# 영등포동1가 지엘리베라움의 검색 결과가 하나가 아니거나 없습니다.
# 영등포동2가 여의도리미티오148의 정보 담기를 4번까지 완료하였습니다.
# 이촌동 G&D용산드림의 검색 결과가 하나가 아니거나 없습니다.
# 한강로3가 센트럴파크의 정보 담기를 6번까지 완료하였습니다.
# 한강로3가 원효전자상가의 검색 결과가 하나가 아니거나 없습니다.
# 한남동 나인원한남의 정보 담기를 6번까지 완료하였습니다.
# 한남동 르가든더메인한남의 정보 담기를 7번까지 완료하였습니다.
# 구산동 벨뷰의 검색 결과가 하나가 아니거나 없습니다.
# 구산동 벽산스카이파크의 정보 담기를 1번까지 완료하였습니다.
# 구산동 새천년드림의 검색 결과가 하나가 아니거나 없습니다.
# 구산동 은평서해그랑블의 정보 담기를 4번까지 완료하였습니다.
# 녹번동 거장메카의 검색 결과가 하나가 아니거나 없습니다.
# 대조동 대경아르체의 정보 담기를 2번까지 완료하였습니다.
# 대조동 베르디움STAY1의 검색 결과가 하나가 아니거나 없습니다.
# 대조동 벽산메트로시티의 정보 담기를 2번까지 완료하였습니다.
# 대조동 북한산포레스트의 정보 담기를 2번까지 완료하였습니다.
# 대조동 영화노블레스의 정보 담기를 4번까지 완료하였습니다.
# 대조동 유진아이디움의 검색 결과가 하나가 아니거나 없습니다.
# 대조동 효민아크로뷰의 정보 담기를 3번까지 완료하였습니다.
# 불광동 경인에버빌의 검색 결과가 하나가 아니거나 없습니다.
# 불광동 디앤제이하우징의 검색 결과가 하나가 아니거나 없습니다.
# 불광동 월드그린의 정보 담기를 7번까지 완료하였습니다.
# 불광동 제이타워의 정보 담기를 3번까지 완료하였습니다.
# 신사동 린든빌의 정보 담기를 1번까지 완료하였습니다.
# 신사동 벨로스의 검색 결과가 하나가 아니거나 없습니다.
# 신사동 연세의 정보 담기를 3번까지 완료하였습니다.
# 역촌동 SM벨리체의 검색 결과가 하나가 아니거나 없습니다.
# 역촌동 도올탑스텔의 검색 결과가 하나가 아니거나 없습니다.
# 역촌동 명남뉴의 검색 결과가 하나가 아니거나 없습니다.
# 역촌동 역촌빌라트의 검색 결과가 하나가 아니거나 없습니다.
# 응암동 e편한세상백련산의 정보 담기를 5번까지 완료하였습니다.
# 응암동 디우아르떼의 검색 결과가 하나가 아니거나 없습니다.
# 응암동 백련산에스케이뷰아이파크의 정보 담기를 5번까지 완료하였습니다.
# 응암동 백련산해모로의 정보 담기를 7번까지 완료하였습니다.
# 응암동 삼영N-CITY의 검색 결과가 하나가 아니거나 없습니다.
# 응암동 신진뉴캐슬의 정보 담기를 3번까지 완료하였습니다.
# 응암동 위산일리온시티의 검색 결과가 하나가 아니거나 없습니다.
# 응암동 청안파인의 정보 담기를 3번까지 완료하였습니다.
# 응암동 펠리시티의 정보 담기를 4번까지 완료하였습니다.
# 명륜2가 아남2의 검색 결과가 하나가 아니거나 없습니다.
# 무악동 경희궁롯데캐슬의 정보 담기를 4번까지 완료하였습니다.
# 신당동 신당KCC스위첸의 정보 담기를 7번까지 완료하였습니다.
# 정동 삼정아트테라스정동의 정보 담기를 6번까지 완료하였습니다.
# 면목동 쌍용더플래티넘용마산의 정보 담기를 3번까지 완료하였습니다.
# 면목동 용마산모아엘가파크포레의 정보 담기를 7번까지 완료하였습니다.
# 면목동 한양수자인사가정파크의 정보 담기를 7번까지 완료하였습니다.
# 신문로2가 디팰리스의 검색 결과가 하나가 아니거나 없습니다.
# 연지동 아르젠종로의 검색 결과가 하나가 아니거나 없습니다.
# 필운동 사직의 검색 결과가 하나가 아니거나 없습니다.
# 신당동 남산FORESTHOUSE의 검색 결과가 하나가 아니거나 없습니다.
# 신당동 다다의 검색 결과가 하나가 아니거나 없습니다.
# 신당동 약수역더시티의 정보 담기를 4번까지 완료하였습니다.
# 신당동 유정의 검색 결과가 하나가 아니거나 없습니다.
# 오장동 오렌지카운티을지로의 정보 담기를 7번까지 완료하였습니다.
# 오장동 오장동오팰리오의 검색 결과가 하나가 아니거나 없습니다.
# 오장동 이지마루오장의 검색 결과가 하나가 아니거나 없습니다.
# 입정동 힐스테이트세운센트럴2단지의 정보 담기를 7번까지 완료하였습니다.
# 장충동1가 상지리츠빌장충동카일룸의 정보 담기를 3번까지 완료하였습니다.
# 충무로5가 충무로헤센스마트의 정보 담기를 6번까지 완료하였습니다.
# 황학동 청계랜드힐의 정보 담기를 7번까지 완료하였습니다.
# 망우동 로얄팰리스주상복합의 정보 담기를 3번까지 완료하였습니다.
# 면목동 라온프라이빗의 정보 담기를 7번까지 완료하였습니다.
# 면목동 사가정센트럴아이파크의 정보 담기를 6번까지 완료하였습니다.
# 면목동 세모하이츠의 정보 담기를 7번까지 완료하였습니다.
# 면목동 이니지오의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 킴스의 검색 결과가 하나가 아니거나 없습니다.
# 묵동 효산센터빌의 정보 담기를 6번까지 완료하였습니다.
# 상봉동 그랑의 정보 담기를 7번까지 완료하였습니다.
# 상봉동 더클래스의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 레그노시티의 정보 담기를 5번까지 완료하였습니다.
# 상봉동 리더스의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 상봉베스트원의 정보 담기를 7번까지 완료하였습니다.
# 상봉동 상봉어반뷰의 정보 담기를 5번까지 완료하였습니다.
# 상봉동 상봉힐스테이의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 풍산쉐르빌102동의 검색 결과가 하나가 아니거나 없습니다.
# 신내동 신내아트빌의 정보 담기를 6번까지 완료하였습니다.
# 중화동 한솔e의 정보 담기를 7번까지 완료하였습니다.
# 개포동 그린빌리지의 검색 결과가 하나가 아니거나 없습니다.
# 논현동 그랑디오스의 정보 담기를 6번까지 완료하였습니다.
# 논현동 논현아이파크의 검색 결과가 하나가 아니거나 없습니다.
# 논현동 비쥬힐의 정보 담기를 4번까지 완료하였습니다.
# 논현동 애플타운의 정보 담기를 6번까지 완료하였습니다.
# 논현동 요진보네르의 정보 담기를 7번까지 완료하였습니다.
# 논현동 펜트힐루논현의 검색 결과가 하나가 아니거나 없습니다.
# 대치동 풍림아이원4차의 정보 담기를 2번까지 완료하였습니다.
# 도곡동 PLUMHILLS의 검색 결과가 하나가 아니거나 없습니다.
# 도곡동 그랜빌캐슬의 정보 담기를 7번까지 완료하였습니다.
# 도곡동 도곡스타빌의 정보 담기를 5번까지 완료하였습니다.
# 도곡동 도곡현대힐스테이트105동의 검색 결과가 하나가 아니거나 없습니다.
# 도곡동 현대향목빌라트의 검색 결과가 하나가 아니거나 없습니다.
# 삼성동 블루밍하우스의 정보 담기를 2번까지 완료하였습니다.
# 삼성동 아셈의 검색 결과가 하나가 아니거나 없습니다.
# 삼성동 엘에이치삼성도시형생활주택의 검색 결과가 하나가 아니거나 없습니다.
# 삼성동 이안애빌의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 Bienestar의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 공간쉐르빌의 정보 담기를 7번까지 완료하였습니다.
# 역삼동 마이다스힐빌라트의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 역삼엔스위트102동의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 PH129의 정보 담기를 2번까지 완료하였습니다.
# 청담동 대우로얄카운티3의 정보 담기를 3번까지 완료하였습니다.
# 청담동 대우멤버스카운티Ⅱ의 정보 담기를 3번까지 완료하였습니다.
# 청담동 라테라스청담의 정보 담기를 6번까지 완료하였습니다.
# 청담동 마크힐스웨스트윙의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 에비뉴나인티의 정보 담기를 7번까지 완료하였습니다.
# 청담동 연세청담파크빌의 정보 담기를 4번까지 완료하였습니다.
# 청담동 연세힐하우스1의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 청담동마크노빌의 정보 담기를 3번까지 완료하였습니다.
# 청담동 청담파라곤Ⅱ2단지의 정보 담기를 7번까지 완료하였습니다.
# 청담동 청담힐진도의 정보 담기를 6번까지 완료하였습니다.
# 청담동 효성빌라청담101의 검색 결과가 하나가 아니거나 없습니다.
# 성내동 갑지하이린의 정보 담기를 3번까지 완료하였습니다.
# 성내동 강동네스빌의 정보 담기를 6번까지 완료하였습니다.
# 성내동 성내스테이의 정보 담기를 2번까지 완료하였습니다.
# 성내동 에스아이팰리스센트럴성내의 정보 담기를 7번까지 완료하였습니다.
# 성내동 오륜아크로빌의 정보 담기를 7번까지 완료하였습니다.
# 성내동 코랜드빌리지의 정보 담기를 4번까지 완료하였습니다.
# 성내동 파크뷰캐슬의 정보 담기를 1번까지 완료하였습니다.
# 천호동 성인의 정보 담기를 7번까지 완료하였습니다.
# 천호동 엘림스퀘어II의 검색 결과가 하나가 아니거나 없습니다.
# 천호동 창대캐슬의 정보 담기를 4번까지 완료하였습니다.
# 번동 다우의 정보 담기를 2번까지 완료하였습니다.
# 수유동 성덕의 정보 담기를 1번까지 완료하였습니다.
# 수유동 수유다우아트리체의 검색 결과가 하나가 아니거나 없습니다.
# 수유동 예도팔라티움의 정보 담기를 2번까지 완료하였습니다.
# 우이동 성원그린의 정보 담기를 2번까지 완료하였습니다.
# 내발산동 한서1차의 정보 담기를 2번까지 완료하였습니다.
# 등촌동 등촌파밀리에더클래식101동의 검색 결과가 하나가 아니거나 없습니다.
# 등촌동 지엠벨리의 정보 담기를 4번까지 완료하였습니다.
# 방화동 마곡노블리안의 정보 담기를 7번까지 완료하였습니다.
# 방화동 마곡센트레빌의 정보 담기를 6번까지 완료하였습니다.
# 염창동 등촌제이스카이의 정보 담기를 4번까지 완료하였습니다.
# 염창동 세왕네트빌의 검색 결과가 하나가 아니거나 없습니다.
# 염창동 엠그린의 정보 담기를 3번까지 완료하였습니다.
# 화곡동 가화나동의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 강서타워의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 궁전A동의 정보 담기를 6번까지 완료하였습니다.
# 화곡동 동서1,2호의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 디아인스의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 메종드로제의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 세교예지안2차의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 세교예지안6차의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 신원1차의 정보 담기를 3번까지 완료하였습니다.
# 화곡동 에스엠케이의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 오경의 정보 담기를 3번까지 완료하였습니다.
# 화곡동 우성트윈캐슬A동의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 율창의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 일광2차의 정보 담기를 3번까지 완료하였습니다.
# 화곡동 임탑-A의 정보 담기를 3번까지 완료하였습니다.
# 화곡동 창대의 정보 담기를 1번까지 완료하였습니다.
# 화곡동 청송평화의 정보 담기를 2번까지 완료하였습니다.
# 화곡동 팔라이스의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 프라임주택의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 한울의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 화곡동복지다동의 검색 결과가 하나가 아니거나 없습니다.
# 남현동 VIP의 정보 담기를 3번까지 완료하였습니다.
# 남현동 남현현대아이빌라의 검색 결과가 하나가 아니거나 없습니다.
# 남현동 삼원하이츠11차의 정보 담기를 3번까지 완료하였습니다.
# 남현동 예촌그린의 정보 담기를 5번까지 완료하였습니다.
# 남현동 하이파크의 정보 담기를 7번까지 완료하였습니다.
# 봉천동 관악캐스빌의 정보 담기를 7번까지 완료하였습니다.
# 자양동 자양동삼성의 검색 결과가 하나가 아니거나 없습니다.
# 봉천동 삼정의 정보 담기를 2번까지 완료하였습니다.
# 봉천동 하이캐슬101동의 정보 담기를 2번까지 완료하였습니다.
# 신림동 신림스카이의 검색 결과가 하나가 아니거나 없습니다.
# 신림동 웰피아의 정보 담기를 7번까지 완료하였습니다.
# 신림동 지붕위애의 검색 결과가 하나가 아니거나 없습니다.
# 광장동 연세리버빌6차의 정보 담기를 5번까지 완료하였습니다.
# 구의동 AZ0213의 정보 담기를 1번까지 완료하였습니다.
# 구의동 구의자이르네의 정보 담기를 7번까지 완료하였습니다.
# 자양동 유림의 정보 담기를 4번까지 완료하였습니다.
# 자양동 한강아남의 정보 담기를 7번까지 완료하였습니다.
# 중곡동 삼성로얄2의 정보 담기를 7번까지 완료하였습니다.
# 중곡동 엘림퍼스트중곡동의 정보 담기를 3번까지 완료하였습니다.
# 중곡동 진흥아르미의 정보 담기를 2번까지 완료하였습니다.
# 화양동 신원리브웰화양동주상복합의 검색 결과가 하나가 아니거나 없습니다.
# 화양동 위너스힐의 검색 결과가 하나가 아니거나 없습니다.
# 화양동 캠퍼스프라자의 정보 담기를 1번까지 완료하였습니다.
# 화양동 테라팰리스건대1차의 정보 담기를 7번까지 완료하였습니다.
# 개봉동 개봉프라자의 정보 담기를 7번까지 완료하였습니다.
# 개봉동 중앙힐의 정보 담기를 3번까지 완료하였습니다.
# 고척동 예인의 정보 담기를 5번까지 완료하였습니다.
# 구로동 함양주택의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 미래빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 태영빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 구로아트빌라5동의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 대승빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 정창빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 한신빌라의 검색 결과가 하나가 아니거나 없습니다.
# 궁동 궁동에스하임의 검색 결과가 하나가 아니거나 없습니다.
# 궁동 대명하이빌101동의 검색 결과가 하나가 아니거나 없습니다.
# 궁동 대명하이빌102동의 검색 결과가 하나가 아니거나 없습니다.
# 오류동 목화수목원의 정보 담기를 7번까지 완료하였습니다.
# 오류동 미진주택B동의 검색 결과가 하나가 아니거나 없습니다.
# 오류동 시티월드의 정보 담기를 4번까지 완료하였습니다.
# 오류동 오류그린의 검색 결과가 하나가 아니거나 없습니다.
# 오류동 은하수수목원2차의 검색 결과가 하나가 아니거나 없습니다.
# 온수동 온수동의 검색 결과가 하나가 아니거나 없습니다.
# 가산동 드림케슬3차의 정보 담기를 1번까지 완료하였습니다.
# 가산동 원평5차의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 리치힐102동의 정보 담기를 1번까지 완료하였습니다.
# 독산동 한솔아트빌라의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 한아프라임102동의 검색 결과가 하나가 아니거나 없습니다.
# 시흥동 에벤에셀프라자의 정보 담기를 3번까지 완료하였습니다.
# 방학동 한원힐트리움아레나의 정보 담기를 2번까지 완료하였습니다.
# 쌍문동 그린스테이트의 정보 담기를 2번까지 완료하였습니다.
# 쌍문동 솔밭노블리안의 정보 담기를 7번까지 완료하였습니다.
# 쌍문동 쌍문동LG트윈빌2의 정보 담기를 2번까지 완료하였습니다.
# 쌍문동 피스플하우스의 정보 담기를 7번까지 완료하였습니다.
# 창동 금성파크A동의 검색 결과가 하나가 아니거나 없습니다.
# 창동 세인트라디움의 정보 담기를 3번까지 완료하였습니다.
# 창동 영창하모니A의 검색 결과가 하나가 아니거나 없습니다.
# 용두동 동대문베네스트의 검색 결과가 하나가 아니거나 없습니다.
# 용두동 서안팰리스의 정보 담기를 7번까지 완료하였습니다.
# 장안동 U포그니2차의 정보 담기를 7번까지 완료하였습니다.
# 장안동 브이티스타일의 정보 담기를 7번까지 완료하였습니다.
# 장안동 아르떼하임의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 에스아이팰리스장안센텀의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 청명에버아트1차의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 청명에버아트2차의 검색 결과가 하나가 아니거나 없습니다.
# 전농동 리베르떼의 검색 결과가 하나가 아니거나 없습니다.
# 제기동 건영스타밸리의 정보 담기를 7번까지 완료하였습니다.
# 제기동 명경아트빌의 검색 결과가 하나가 아니거나 없습니다.
# 제기동 어반넥서스의 검색 결과가 하나가 아니거나 없습니다.
# 제기동 효성트럼프의 정보 담기를 7번까지 완료하였습니다.
# 회기동 동일스카이시티2차의 정보 담기를 7번까지 완료하였습니다.
# 대방동 보라매센트럴타운의 검색 결과가 하나가 아니거나 없습니다.
# 사당동 해맑은의 정보 담기를 6번까지 완료하였습니다.
# 상도동 원의 정보 담기를 3번까지 완료하였습니다.
# 상도동 장승의 정보 담기를 7번까지 완료하였습니다.
# 상도동 현산푸른숲의 정보 담기를 7번까지 완료하였습니다.
# 신대방동 동작협성휴포레시그니처의 검색 결과가 하나가 아니거나 없습니다.
# 흑석동 MARKHILLS의 검색 결과가 하나가 아니거나 없습니다.
# 망원동 광남캐스빌D의 검색 결과가 하나가 아니거나 없습니다.
# 망원동 마포월드컵제이스카이의 검색 결과가 하나가 아니거나 없습니다.
# 망원동 솔루체의 정보 담기를 6번까지 완료하였습니다.
# 서교동 센트레의 정보 담기를 4번까지 완료하였습니다.
# 성산동 성산힐의 정보 담기를 7번까지 완료하였습니다.
# 성산동 유안의 정보 담기를 7번까지 완료하였습니다.
# 성산동 한림101동의 정보 담기를 7번까지 완료하였습니다.
# 성산동 해피존2의 검색 결과가 하나가 아니거나 없습니다.
# 신공덕동 블레스하임의 검색 결과가 하나가 아니거나 없습니다.
# 용강동 대호강변의 정보 담기를 2번까지 완료하였습니다.
# 중동 백명TRENDYAPT의 정보 담기를 3번까지 완료하였습니다.
# 창전동 중앙하이츠103동의 검색 결과가 하나가 아니거나 없습니다.
# 합정동 펠리스아트빌의 정보 담기를 2번까지 완료하였습니다.
# 남가좌동 DMC금호리첸시아의 정보 담기를 5번까지 완료하였습니다.
# 연희동 제니스APT의 정보 담기를 7번까지 완료하였습니다.
# 창천동 씨밀레의 정보 담기를 7번까지 완료하였습니다.
# 창천동 엘르빌2차의 정보 담기를 7번까지 완료하였습니다.
# 홍은동 교수의 정보 담기를 7번까지 완료하였습니다.
# 홍은동 명가의 정보 담기를 5번까지 완료하였습니다.
# 홍은동 세윤외인빌리지의 검색 결과가 하나가 아니거나 없습니다.
# 홍제동 제니스뷰의 정보 담기를 7번까지 완료하였습니다.
# 홍제동 홍제헤렌의 정보 담기를 7번까지 완료하였습니다.
# 반포동 몽마르뜨파크의 검색 결과가 하나가 아니거나 없습니다.
# 반포동 비버리힐즈의 정보 담기를 2번까지 완료하였습니다.
# 반포동 상지리츠빌2차의 정보 담기를 5번까지 완료하였습니다.
# 반포동 청광아트빌라12의 정보 담기를 1번까지 완료하였습니다.
# 반포동 타운빌의 정보 담기를 6번까지 완료하였습니다.
# 방배동 노블하임의 정보 담기를 2번까지 완료하였습니다.
# 방배동 대건딜라이트의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 리벨루스의 정보 담기를 6번까지 완료하였습니다.
# 방배동 방배호원의 정보 담기를 4번까지 완료하였습니다.
# 방배동 방배힐1차의 정보 담기를 4번까지 완료하였습니다.
# 방배동 상지리츠빌7차의 정보 담기를 4번까지 완료하였습니다.
# 방배동 아이리스의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 캐슬렉스의 정보 담기를 2번까지 완료하였습니다.
# 방배동 태화빌라의 정보 담기를 1번까지 완료하였습니다.
# 서초동 DK밸리뷰서초2차의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 대경벨로체의 정보 담기를 5번까지 완료하였습니다.
# 서초동 디아레나서초의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 서린의 정보 담기를 7번까지 완료하였습니다.
# 서초동 서초트레져의 정보 담기를 2번까지 완료하였습니다.
# 서초동 서초힐하우스의 정보 담기를 3번까지 완료하였습니다.
# 서초동 트라움하우스2의 정보 담기를 2번까지 완료하였습니다.
# 양재동 경희궁의 정보 담기를 7번까지 완료하였습니다.
# 양재동 동원그린의 정보 담기를 5번까지 완료하였습니다.
# 양재동 삼익양재빌라의 정보 담기를 5번까지 완료하였습니다.
# 양재동 현대테라하임101동의 정보 담기를 7번까지 완료하였습니다.
# 양재동 휴먼씨티의 정보 담기를 4번까지 완료하였습니다.
# 마장동 행복드림의 정보 담기를 4번까지 완료하였습니다.
# 성수동2가 이화102동의 검색 결과가 하나가 아니거나 없습니다.
# 옥수동 모닝빌의 정보 담기를 2번까지 완료하였습니다.
# 보문동3가 코지아뜨리에의 검색 결과가 하나가 아니거나 없습니다.
# 성북동 주암의 정보 담기를 1번까지 완료하였습니다.
# 안암동3가 동관아트빌의 정보 담기를 4번까지 완료하였습니다.
# 가락동 금성프라자1의 검색 결과가 하나가 아니거나 없습니다.
# 가락동 신한빌라트-신한미지엔의 검색 결과가 하나가 아니거나 없습니다.
# 가락동 주성파크빌의 정보 담기를 6번까지 완료하였습니다.
# 가락동 테라펠리체송파의 정보 담기를 5번까지 완료하였습니다.
# 마천동 송파건원여미지의 정보 담기를 2번까지 완료하였습니다.
# 오금동 송파레미니스2단지의 정보 담기를 5번까지 완료하였습니다.
# 마천동 한주리버뷰의 정보 담기를 4번까지 완료하였습니다.
# 방이동 에비뉴잠실의 검색 결과가 하나가 아니거나 없습니다.
# 방이동 트리니엘의 정보 담기를 5번까지 완료하였습니다.
# 방이동 해태그린피아빌라트의 정보 담기를 2번까지 완료하였습니다.
# 석촌동 예명의 정보 담기를 4번까지 완료하였습니다.
# 송파동 엘에이치송파도시형생활주택의 검색 결과가 하나가 아니거나 없습니다.
# 송파동 위례캐스빌의 검색 결과가 하나가 아니거나 없습니다.
# 오금동 슈프림하우스의 검색 결과가 하나가 아니거나 없습니다.
# 잠실동 앙시레이크타워의 정보 담기를 7번까지 완료하였습니다.
# 목동 동도빌라트의 정보 담기를 3번까지 완료하였습니다.
# 목동 목동휘버스II의 검색 결과가 하나가 아니거나 없습니다.
# 목동 상진지오밸리가동의 정보 담기를 4번까지 완료하였습니다.
# 목동 힐타운의 정보 담기를 3번까지 완료하였습니다.
# 신월동 대운2차의 정보 담기를 7번까지 완료하였습니다.
# 신월동 두원A동의 정보 담기를 4번까지 완료하였습니다.
# 신월동 로즈그린타운의 정보 담기를 3번까지 완료하였습니다.
# 신월동 양천홈타운1차의 정보 담기를 7번까지 완료하였습니다.
# 신월동 양천홈타운2차의 정보 담기를 7번까지 완료하였습니다.
# 신월동 조광의 정보 담기를 6번까지 완료하였습니다.
# 신월동 태산의 정보 담기를 2번까지 완료하였습니다.
# 신정동 목동무지개의 정보 담기를 5번까지 완료하였습니다.
# 신정동 목동해오름101동의 검색 결과가 하나가 아니거나 없습니다.
# 신정동 영림의 정보 담기를 7번까지 완료하였습니다.
# 신정동 제일에비앙102동의 검색 결과가 하나가 아니거나 없습니다.
# 신정동 중앙하이츠목동펠리시티의 검색 결과가 하나가 아니거나 없습니다.
# 신정동 청자의 검색 결과가 하나가 아니거나 없습니다.
# 당산동 성재I캐슬2차의 정보 담기를 2번까지 완료하였습니다.
# 신길동 루나플라체의 검색 결과가 하나가 아니거나 없습니다.
# 영등포동7가 여의휴젠느의 검색 결과가 하나가 아니거나 없습니다.
# 용문동 대호드림빌의 검색 결과가 하나가 아니거나 없습니다.
# 이태원동 준아트빌의 정보 담기를 6번까지 완료하였습니다.
# 한강로3가 전자타운한신의 정보 담기를 2번까지 완료하였습니다.
# 한남동 파르크한남의 정보 담기를 7번까지 완료하였습니다.
# 한남동 형우베스트빌3차의 검색 결과가 하나가 아니거나 없습니다.
# 효창동 효창로즈의 검색 결과가 하나가 아니거나 없습니다.
# 갈현동 아름의 정보 담기를 1번까지 완료하였습니다.
# 갈현동 한아름의 정보 담기를 7번까지 완료하였습니다.
# 구산동 에덴드림의 정보 담기를 4번까지 완료하였습니다.
# 구산동 우공아트빌의 정보 담기를 7번까지 완료하였습니다.
# 구산동 천지로얄의 정보 담기를 2번까지 완료하였습니다.
# 녹번동 DH팰리스타워의 검색 결과가 하나가 아니거나 없습니다.
# 대조동 제이타워1의 정보 담기를 4번까지 완료하였습니다.
# 대조동 제이타워3의 정보 담기를 3번까지 완료하였습니다.
# 대조동 해오름시티의 검색 결과가 하나가 아니거나 없습니다.
# 불광동 대광월드의 정보 담기를 7번까지 완료하였습니다.
# 불광동 쉐라톤의 정보 담기를 5번까지 완료하였습니다.
# 불광동 연신내역트리플라101동의 검색 결과가 하나가 아니거나 없습니다.
# 수색동 DMCSKVIEW의 검색 결과가 하나가 아니거나 없습니다.
# 신사동 신선의 정보 담기를 6번까지 완료하였습니다.
# 신사동 예성그린의 정보 담기를 4번까지 완료하였습니다.
# 신사동 정은노블스B의 검색 결과가 하나가 아니거나 없습니다.
# 역촌동 건우샹그리라의 정보 담기를 3번까지 완료하였습니다.
# 역촌동 고도의 검색 결과가 하나가 아니거나 없습니다.
# 역촌동 역산미르빌의 정보 담기를 3번까지 완료하였습니다.
# 역촌동 진주하이츠의 검색 결과가 하나가 아니거나 없습니다.
# 역촌동 청우참조은의 정보 담기를 2번까지 완료하였습니다.
# 응암동 우리스페이스의 정보 담기를 1번까지 완료하였습니다.
# 응암동 월드빌의 정보 담기를 5번까지 완료하였습니다.
# 명륜1가 방산의 검색 결과가 하나가 아니거나 없습니다.
# 수송동 로얄팰리스스위트의 검색 결과가 하나가 아니거나 없습니다.
# 필운동 신동아블루아광화문의꿈의 검색 결과가 하나가 아니거나 없습니다.
# 효제동 이지마루종로의 검색 결과가 하나가 아니거나 없습니다.
# 신당동 우석의 검색 결과가 하나가 아니거나 없습니다.
# 신당동 청구드림의 정보 담기를 6번까지 완료하였습니다.
# 신당동 탑힐의 검색 결과가 하나가 아니거나 없습니다.
# 회현동1가 평화의 정보 담기를 2번까지 완료하였습니다.
# 면목동 면목루브루의 정보 담기를 6번까지 완료하였습니다.
# 묵동 성원팰리스의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 e-푸른나동의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 동성네스트빌1동의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 상봉태솔의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 센트럴파크55의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 솔렌시아3의 검색 결과가 하나가 아니거나 없습니다.
# 개포동 개포2차현대의 검색 결과가 하나가 아니거나 없습니다.
# 개포동 포이벨리의 정보 담기를 1번까지 완료하였습니다.
# 개포동 한림의 정보 담기를 1번까지 완료하였습니다.
# 논현동 더그레이스의 정보 담기를 3번까지 완료하였습니다.
# 논현동 라이헤스빌의 정보 담기를 6번까지 완료하였습니다.
# 논현동 은탑리더스카운티의 정보 담기를 7번까지 완료하였습니다.
# 논현동 테크노빌라트의 정보 담기를 7번까지 완료하였습니다.
# 논현동 현대넥서스B동의 검색 결과가 하나가 아니거나 없습니다.
# 대치동 노빌리티빌리지의 정보 담기를 6번까지 완료하였습니다.
# 도곡동 로덴하우스웨스트빌리지의 정보 담기를 2번까지 완료하였습니다.
# 도곡동 로덴하우스이스트빌리지의 정보 담기를 2번까지 완료하였습니다.
# 도곡동 리치아르떼빌의 정보 담기를 6번까지 완료하였습니다.
# 삼성동 대우멤버스카운티301의 검색 결과가 하나가 아니거나 없습니다.
# 삼성동 삼성웰피아의 정보 담기를 3번까지 완료하였습니다.
# 삼성동 심포니하우스의 정보 담기를 7번까지 완료하였습니다.
# 삼성동 우정에쉐르2의 정보 담기를 5번까지 완료하였습니다.
# 삼성동 월성빌라트의 정보 담기를 5번까지 완료하였습니다.
# 삼성동 현대삼성동1차의 정보 담기를 4번까지 완료하였습니다.
# 역삼동 강남한솔의 정보 담기를 4번까지 완료하였습니다.
# 역삼동 명인갤러리의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 시티프라디움더강남201동의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 쎄비앙102동의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 역삼이안애에이의 정보 담기를 4번까지 완료하였습니다.
# 역삼동 현대이스트빌의 정보 담기를 2번까지 완료하였습니다.
# 청담동 상지리츠빌9차의 정보 담기를 2번까지 완료하였습니다.
# 청담동 상지리츠빌카일룸3차의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 청담그랑빌의 정보 담기를 7번까지 완료하였습니다.
# 청담동 청담대우멤버스카운티7차의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 청담동현대빌라트의 정보 담기를 3번까지 완료하였습니다.
# 청담동 호원빌라의 정보 담기를 5번까지 완료하였습니다.
# 길동 광남캐스빌610V의 정보 담기를 7번까지 완료하였습니다.
# 길동 삼유스위트빌의 정보 담기를 5번까지 완료하였습니다.
# 길동 양촌의 정보 담기를 2번까지 완료하였습니다.
# 둔촌동 KNP이스트빌의 정보 담기를 5번까지 완료하였습니다.
# 둔촌동 도원빌의 정보 담기를 5번까지 완료하였습니다.
# 둔촌동 상상프리의 정보 담기를 4번까지 완료하였습니다.
# 둔촌동 케이엔피로얄의 검색 결과가 하나가 아니거나 없습니다.
# 명일동 우성103동의 검색 결과가 하나가 아니거나 없습니다.
# 명일동 태천해오름102동B의 검색 결과가 하나가 아니거나 없습니다.
# 명일동 태천해오름103동의 정보 담기를 6번까지 완료하였습니다.
# 성내동 노블네스트의 검색 결과가 하나가 아니거나 없습니다.
# 성내동 라움포레의 정보 담기를 7번까지 완료하였습니다.
# 성내동 올림픽파크플러스의 정보 담기를 2번까지 완료하였습니다.
# 성내동 집앤사베니의 정보 담기를 1번까지 완료하였습니다.
# 성내동 집앤사비카의 정보 담기를 7번까지 완료하였습니다.
# 성내동 한솔애리즈601동의 검색 결과가 하나가 아니거나 없습니다.
# 성내동 현대토파즈의 정보 담기를 4번까지 완료하였습니다.
# 성내동 힐데스하임올림픽파크의 정보 담기를 6번까지 완료하였습니다.
# 암사동 대송의 정보 담기를 2번까지 완료하였습니다.
# 암사동 대의아름누리의 정보 담기를 7번까지 완료하였습니다.
# 암사동 양지벨로스의 정보 담기를 6번까지 완료하였습니다.
# 천호동 강동파크빌의 정보 담기를 2번까지 완료하였습니다.
# 천호동 부강의 정보 담기를 4번까지 완료하였습니다.
# 천호동 신동양빛여울의 정보 담기를 7번까지 완료하였습니다.
# 천호동 집앤사스윗사이드의 정보 담기를 2번까지 완료하였습니다.
# 미아동 동아하이빌14차의 검색 결과가 하나가 아니거나 없습니다.
# 미아동 월드빌라의 검색 결과가 하나가 아니거나 없습니다.
# 미아동 인성의 정보 담기를 7번까지 완료하였습니다.
# 번동 더조은홈의 정보 담기를 3번까지 완료하였습니다.
# 수유동 JKapartment의 검색 결과가 하나가 아니거나 없습니다.
# 수유동 북한산스카이뷰의 정보 담기를 7번까지 완료하였습니다.
# 수유동 삼성빌리지의 검색 결과가 하나가 아니거나 없습니다.
# 우이동 다인플레움의 정보 담기를 7번까지 완료하였습니다.
# 공항동 발쿠치네하우스의 정보 담기를 7번까지 완료하였습니다.
# 내발산동 내츄럴2차의 정보 담기를 5번까지 완료하였습니다.
# 내발산동 내츄럴4차의 정보 담기를 7번까지 완료하였습니다.
# 내발산동 덕현중앙타워빌의 검색 결과가 하나가 아니거나 없습니다.
# 내발산동 예스빌의 정보 담기를 4번까지 완료하였습니다.
# 내발산동 쥴리앙의 검색 결과가 하나가 아니거나 없습니다.
# 방화동 성옥의 정보 담기를 1번까지 완료하였습니다.
# 화곡동 광영다모은정의 정보 담기를 4번까지 완료하였습니다.
# 화곡동 다담센트빌의 정보 담기를 1번까지 완료하였습니다.
# 화곡동 대종의 정보 담기를 4번까지 완료하였습니다.
# 화곡동 임탑-B의 정보 담기를 1번까지 완료하였습니다.
# 화곡동 주얼리의 정보 담기를 7번까지 완료하였습니다.
# 화곡동 태성비리치의 정보 담기를 3번까지 완료하였습니다.
# 화곡동 태영그린의 정보 담기를 1번까지 완료하였습니다.
# 화곡동 태흥그랑뷰의 정보 담기를 6번까지 완료하였습니다.
# 화곡동 효성A의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 효성B의 검색 결과가 하나가 아니거나 없습니다.
# 남현동 노블스톤의 정보 담기를 6번까지 완료하였습니다.
# 남현동 로미아트빌의 정보 담기를 4번까지 완료하였습니다.
# 남현동 쎈트앤빌2의 검색 결과가 하나가 아니거나 없습니다.
# 남현동 예촌하이츠빌의 정보 담기를 6번까지 완료하였습니다.
# 남현동 카사빌의 정보 담기를 7번까지 완료하였습니다.
# 봉천동 경원로얄시티의 정보 담기를 4번까지 완료하였습니다.
# 봉천동 신부의 검색 결과가 하나가 아니거나 없습니다.
# 봉천동 에이스인헌의 정보 담기를 4번까지 완료하였습니다.
# 봉천동 탑의 검색 결과가 하나가 아니거나 없습니다.
# 봉천동 푸르빌2차의 검색 결과가 하나가 아니거나 없습니다.
# 신림동 동훈CDI의 검색 결과가 하나가 아니거나 없습니다.
# 신림동 로마의 정보 담기를 5번까지 완료하였습니다.
# 신림동 벨라루체의 정보 담기를 3번까지 완료하였습니다.
# 신림동 상목에버빌A의 정보 담기를 5번까지 완료하였습니다.
# 구의동 강변에스케이뷰의 검색 결과가 하나가 아니거나 없습니다.
# 구의동 광진파크프라이빗의 정보 담기를 7번까지 완료하였습니다.
# 구의동 데쟈뷰의 정보 담기를 7번까지 완료하였습니다.
# 구의동 성원쌍떼빌의 검색 결과가 하나가 아니거나 없습니다.
# 중곡동 두리의 정보 담기를 4번까지 완료하였습니다.
# 중곡동 삼보글로벌101동의 검색 결과가 하나가 아니거나 없습니다.
# 중곡동 삼보글로벌102동의 정보 담기를 7번까지 완료하였습니다.
# 고척동 예주유니츠의 정보 담기를 2번까지 완료하였습니다.
# 구로동 옥천빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 경원주택6동의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 부국주택의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 돌담의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 800-27의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 800-30의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 801-14의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 801-9의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 경성빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 구로아트빌라4동의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 낙원빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 대림빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 대영빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 동산빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 동산빌라1동의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 미도빌라A동의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 미성빌라트의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 삼호빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 서원빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 선진빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 안정빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 청송빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 청우아트빌라3차의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 태영빌라2의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 풍안주택의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 한양하이츠의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 현암B동의 검색 결과가 하나가 아니거나 없습니다.
# 궁동 다청림101동의 검색 결과가 하나가 아니거나 없습니다.
# 오류동 계림웨스트벨리의 검색 결과가 하나가 아니거나 없습니다.
# 오류동 골든팰리스의 정보 담기를 5번까지 완료하였습니다.
# 오류동 목화수목원102동의 정보 담기를 7번까지 완료하였습니다.
# 오류동 미진주택A동의 검색 결과가 하나가 아니거나 없습니다.
# 항동 유한오크팰리스의 정보 담기를 5번까지 완료하였습니다.
# 항동 항동제일풍경채포레스트의 정보 담기를 3번까지 완료하였습니다.
# 독산동 동은5차의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 리치힐의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 리치힐101동의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 문성의 정보 담기를 1번까지 완료하였습니다.
# 독산동 세진웰빙101의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 세진웰빙102의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 은탑로얄클라스의 검색 결과가 하나가 아니거나 없습니다.
# 독산동 청호센트레빌의 정보 담기를 1번까지 완료하였습니다.
# 독산동 한아마인드의 정보 담기를 2번까지 완료하였습니다.
# 시흥동 낙원의 정보 담기를 2번까지 완료하였습니다.
# 시흥동 백운스위트빌의 정보 담기를 7번까지 완료하였습니다.
# 시흥동 백운플러스타워의 정보 담기를 6번까지 완료하였습니다.
# 시흥동 우림메르디앙의 검색 결과가 하나가 아니거나 없습니다.
# 공릉동 서경하누리의 정보 담기를 2번까지 완료하였습니다.
# 상계동 D.S의 검색 결과가 하나가 아니거나 없습니다.
# 상계동 보람그린102동의 정보 담기를 7번까지 완료하였습니다.
# 상계동 보미의 정보 담기를 1번까지 완료하였습니다.
# 상계동 센트럴타워의 정보 담기를 4번까지 완료하였습니다.
# 상계동 수락파크의 정보 담기를 6번까지 완료하였습니다.
# 월계동 월계로즈빌의 정보 담기를 5번까지 완료하였습니다.
# 중계동 한신월드의 정보 담기를 6번까지 완료하였습니다.
# 방학동 북한산팰리스의 정보 담기를 5번까지 완료하였습니다.
# 쌍문동 그린힐스의 정보 담기를 4번까지 완료하였습니다.
# 쌍문동 대우파크빌의 정보 담기를 2번까지 완료하였습니다.
# 쌍문동 스마트빌의 정보 담기를 3번까지 완료하였습니다.
# 쌍문동 신성오크힐의 정보 담기를 3번까지 완료하였습니다.
# 쌍문동 쌍문리버뷰의 검색 결과가 하나가 아니거나 없습니다.
# 창동 DK포시즌의 정보 담기를 5번까지 완료하였습니다.
# 창동 금강102의 검색 결과가 하나가 아니거나 없습니다.
# 창동 창동역블루핀2동의 검색 결과가 하나가 아니거나 없습니다.
# 창동 퍼스트뷰의 정보 담기를 4번까지 완료하였습니다.
# 창동 현진의 검색 결과가 하나가 아니거나 없습니다.
# 창동 황지의 정보 담기를 4번까지 완료하였습니다.
# 답십리동 엘림스퀘어3의 정보 담기를 2번까지 완료하였습니다.
# 신설동 더나인의 검색 결과가 하나가 아니거나 없습니다.
# 이문동 민족통일MJ캠퍼스외대2차의 정보 담기를 3번까지 완료하였습니다.
# 이문동 삼보스위트홈의 정보 담기를 7번까지 완료하였습니다.
# 장안동 JS의 정보 담기를 7번까지 완료하였습니다.
# 장안동 SM이로빌4차B동의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 대성장안애캐슬의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 삼현팰리체의 정보 담기를 7번까지 완료하였습니다.
# 장안동 새한그린빌의 정보 담기를 6번까지 완료하였습니다.
# 장안동 장안동공감대의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 장안동파크뷰의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 제이슨의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 젬스톤힐즈의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 태솔타운3차의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 현대리노빌102동의 검색 결과가 하나가 아니거나 없습니다.
# 대방동 디어파크의 정보 담기를 7번까지 완료하였습니다.
# 사당동 라이즈1동의 정보 담기를 7번까지 완료하였습니다.
# 사당동 오림센트빌의 정보 담기를 7번까지 완료하였습니다.
# 사당동 이수프라자의 정보 담기를 7번까지 완료하였습니다.
# 상도동 다온의 정보 담기를 7번까지 완료하였습니다.
# 상도동 드림캐슬타워의 검색 결과가 하나가 아니거나 없습니다.
# 상도동 정호힐사이드의 정보 담기를 7번까지 완료하였습니다.
# 노고산동 신촌다올노블리움의 검색 결과가 하나가 아니거나 없습니다.
# 망원동 삼우하이뷰의 정보 담기를 7번까지 완료하였습니다.
# 망원동 세광의 정보 담기를 6번까지 완료하였습니다.
# 망원동 태경크레앙스의 정보 담기를 7번까지 완료하였습니다.
# 서교동 신세계드림빌의 정보 담기를 6번까지 완료하였습니다.
# 성산동 한림201동의 정보 담기를 3번까지 완료하였습니다.
# 염리동 유풍의 정보 담기를 4번까지 완료하였습니다.
# 창전동 대원파크빌의 정보 담기를 6번까지 완료하였습니다.
# 합정동 대운행복의 정보 담기를 7번까지 완료하였습니다.
# 합정동 리버아인의 정보 담기를 5번까지 완료하였습니다.
# 합정동 합정한강의 정보 담기를 2번까지 완료하였습니다.
# 남가좌동 엠화일에이동의 정보 담기를 7번까지 완료하였습니다.
# 북가좌동 성암의 정보 담기를 4번까지 완료하였습니다.
# 북가좌동 청솔하이츠1동의 정보 담기를 7번까지 완료하였습니다.
# 연희동 동도아카데미하우스2차의 정보 담기를 7번까지 완료하였습니다.
# 연희동 로엠아트빌의 검색 결과가 하나가 아니거나 없습니다.
# 연희동 리베르떼-빌의 정보 담기를 3번까지 완료하였습니다.
# 연희동 파크빌의 정보 담기를 5번까지 완료하였습니다.
# 연희동 파크카운티의 정보 담기를 3번까지 완료하였습니다.
# 홍은동 Elleville의 검색 결과가 하나가 아니거나 없습니다.
# 홍은동 신원지벤스타3의 검색 결과가 하나가 아니거나 없습니다.
# 홍은동 장성미모아의 검색 결과가 하나가 아니거나 없습니다.
# 홍은동 제이씨라디앙의 검색 결과가 하나가 아니거나 없습니다.
# 홍제동 그레이스A동의 검색 결과가 하나가 아니거나 없습니다.
# 홍제동 송도그린빌A동의 검색 결과가 하나가 아니거나 없습니다.
# 홍제동 제니스의 정보 담기를 7번까지 완료하였습니다.
# 홍제동 풍진베이스타운의 정보 담기를 6번까지 완료하였습니다.
# 반포동 반포파크빌의 검색 결과가 하나가 아니거나 없습니다.
# 반포동 보아스힐의 정보 담기를 3번까지 완료하였습니다.
# 반포동 삼광의 정보 담기를 6번까지 완료하였습니다.
# 반포동 써니힐의 정보 담기를 6번까지 완료하였습니다.
# 반포동 윌턴빌의 검색 결과가 하나가 아니거나 없습니다.
# 반포동 태평아트의 정보 담기를 7번까지 완료하였습니다.
# 반포동 효성빌라26동의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 UPPERHOUSE의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 강남아트빌의 정보 담기를 6번까지 완료하였습니다.
# 방배동 공작빌라트의 정보 담기를 2번까지 완료하였습니다.
# 방배동 그랑씨엘2000의 정보 담기를 4번까지 완료하였습니다.
# 방배동 나인빌의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 네스코의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 노블씨티의 정보 담기를 5번까지 완료하였습니다.
# 방배동 동광빌라트의 정보 담기를 7번까지 완료하였습니다.
# 방배동 디오엠프리미어의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 라온채의 정보 담기를 6번까지 완료하였습니다.
# 방배동 라파예트의 정보 담기를 4번까지 완료하였습니다.
# 방배동 레베빌2의 정보 담기를 4번까지 완료하였습니다.
# 방배동 리치팰리스의 정보 담기를 3번까지 완료하였습니다.
# 방배동 방배2차상지리츠빌의 정보 담기를 2번까지 완료하였습니다.
# 방배동 방배동갤러리하우스3의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 방배비젼21빌라트의 정보 담기를 7번까지 완료하였습니다.
# 방배동 방배삼성홈타운의 정보 담기를 7번까지 완료하였습니다.
# 방배동 방배신주의 정보 담기를 7번까지 완료하였습니다.
# 방배동 방배아트e-편한세상102의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 방배엔스위트의 정보 담기를 4번까지 완료하였습니다.
# 방배동 방배타운하우스의 정보 담기를 6번까지 완료하였습니다.
# 방배동 방배트리플의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 방배힐2차의 정보 담기를 2번까지 완료하였습니다.
# 방배동 벨루체팰리스의 정보 담기를 5번까지 완료하였습니다.
# 방배동 서리풀래디앙의 정보 담기를 7번까지 완료하였습니다.
# 방배동 서리풀프라젠의 정보 담기를 4번까지 완료하였습니다.
# 방배동 선영베스트의 정보 담기를 5번까지 완료하였습니다.
# 방배동 성지라빌레뜨B의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 세양아르비채102동의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 신구하이텍빌리지의 정보 담기를 3번까지 완료하였습니다.
# 방배동 신호나이스빌의 정보 담기를 4번까지 완료하였습니다.
# 방배동 파인빌리지의 정보 담기를 3번까지 완료하였습니다.
# 방배동 프라하임1차의 정보 담기를 4번까지 완료하였습니다.
# 방배동 프레스턴의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 한화엘르빌의 정보 담기를 4번까지 완료하였습니다.
# 방배동 현대쉴러하우스의 정보 담기를 7번까지 완료하였습니다.
# 방배동 현대아르빌의 정보 담기를 3번까지 완료하였습니다.
# 방배동 현대오페라하우스2차의 정보 담기를 7번까지 완료하였습니다.
# 방배동 효산빌라트의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 더샵오데움의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 도무스의 정보 담기를 3번까지 완료하였습니다.
# 서초동 동아빌리지의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 로얄하이츠의 정보 담기를 2번까지 완료하였습니다.
# 서초동 마샹스의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 서초대성유니드의 정보 담기를 2번까지 완료하였습니다.
# 서초동 서초동에지앙의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 서초드림하이츠의 정보 담기를 7번까지 완료하였습니다.
# 서초동 서초블레스의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 서초블리스의 정보 담기를 7번까지 완료하였습니다.
# 서초동 월드메르디앙A의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 한승미메이드의 정보 담기를 7번까지 완료하였습니다.
# 서초동 햄프턴코트의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 현대서초빌라트의 검색 결과가 하나가 아니거나 없습니다.
# 양재동 누리빌의 정보 담기를 2번까지 완료하였습니다.
# 양재동 대흥의 정보 담기를 5번까지 완료하였습니다.
# 양재동 서초파크빌의 정보 담기를 5번까지 완료하였습니다.
# 양재동 시그마의 정보 담기를 5번까지 완료하였습니다.
# 양재동 양재테크노3의 정보 담기를 7번까지 완료하였습니다.
# 양재동 해청파인빌의 검색 결과가 하나가 아니거나 없습니다.
# 잠원동 신반포26의 정보 담기를 2번까지 완료하였습니다.
# 금호동4가 리버마이다스빌의 정보 담기를 3번까지 완료하였습니다.
# 마장동 마장동해맑은의 정보 담기를 4번까지 완료하였습니다.
# 마장동 삼웅의 정보 담기를 4번까지 완료하였습니다.
# 마장동 한건토파즈빌의 정보 담기를 1번까지 완료하였습니다.
# 옥수동 벽산빌라트의 정보 담기를 3번까지 완료하였습니다.
# 하왕십리동 상왕의 정보 담기를 7번까지 완료하였습니다.
# 삼선동3가 동림푸른의 검색 결과가 하나가 아니거나 없습니다.
# 삼선동3가 유니아테라스의 정보 담기를 5번까지 완료하였습니다.
# 성북동1가 스타팰리스의 정보 담기를 7번까지 완료하였습니다.
# 정릉동 대창쉐르빌의 정보 담기를 6번까지 완료하였습니다.
# 종암동 중앙드림빌의 정보 담기를 4번까지 완료하였습니다.
# 가락동 금홍해오름의 정보 담기를 1번까지 완료하였습니다.
# 가락동 동궁리치웰1의 정보 담기를 3번까지 완료하였습니다.
# 가락동 동부썬빌의 검색 결과가 하나가 아니거나 없습니다.
# 가락동 아키죤II의 검색 결과가 하나가 아니거나 없습니다.
# 마천동 다우림의 정보 담기를 1번까지 완료하였습니다.
# 마천동 대성스카이뷰의 정보 담기를 4번까지 완료하였습니다.
# 마천동 천마그랑밸리의 정보 담기를 7번까지 완료하였습니다.
# 문정동 주성파크뷰의 정보 담기를 3번까지 완료하였습니다.
# 방이동 AQUADCASAS의 검색 결과가 하나가 아니거나 없습니다.
# 방이동 도무스빌의 정보 담기를 1번까지 완료하였습니다.
# 방이동 이스턴잠실의 검색 결과가 하나가 아니거나 없습니다.
# 방이동 주함위너스Ⅰ의 검색 결과가 하나가 아니거나 없습니다.
# 삼전동 동원아이파크의 정보 담기를 5번까지 완료하였습니다.
# 오금동 더뷰21의 정보 담기를 2번까지 완료하였습니다.
# 오금동 우송그린의 정보 담기를 7번까지 완료하였습니다.
# 목동 목동리버힐의 정보 담기를 2번까지 완료하였습니다.
# 목동 목동훼미리의 검색 결과가 하나가 아니거나 없습니다.
# 목동 목동휘버스I의 정보 담기를 1번까지 완료하였습니다.
# 목동 엘리온의 정보 담기를 6번까지 완료하였습니다.
# 목동 효원빌라트의 정보 담기를 2번까지 완료하였습니다.
# 신월동 NEWSK의 검색 결과가 하나가 아니거나 없습니다.
# 신월동 동양브로미B의 검색 결과가 하나가 아니거나 없습니다.
# 신월동 라온미브의 정보 담기를 6번까지 완료하였습니다.
# 신월동 상신의 정보 담기를 7번까지 완료하였습니다.
# 신월동 신라이프의 정보 담기를 3번까지 완료하였습니다.
# 신월동 양천홈타운3차의 정보 담기를 7번까지 완료하였습니다.
# 신월동 영남타운의 정보 담기를 2번까지 완료하였습니다.
# 신월동 용민홈타워빌의 검색 결과가 하나가 아니거나 없습니다.
# 신월동 주함헤븐105동의 검색 결과가 하나가 아니거나 없습니다.
# 신정동 동양부로미의 정보 담기를 2번까지 완료하였습니다.
# 신정동 리치펠리스의 정보 담기를 5번까지 완료하였습니다.
# 신정동 목동해오름103동의 검색 결과가 하나가 아니거나 없습니다.
# 신정동 춘당아네시스의 정보 담기를 6번까지 완료하였습니다.
# 신정동 헤브론의 정보 담기를 2번까지 완료하였습니다.
# 도림동 그린나래의 검색 결과가 하나가 아니거나 없습니다.
# 신길동 시원트레벨의 정보 담기를 1번까지 완료하였습니다.
# 양평동4가 수성예술의 정보 담기를 7번까지 완료하였습니다.
# 양평동4가 에이스리버티움의 정보 담기를 3번까지 완료하였습니다.
# 동빙고동 SOD빌의 검색 결과가 하나가 아니거나 없습니다.
# 동빙고동 파인힐빌의 정보 담기를 5번까지 완료하였습니다.
# 원효로1가 로얄카운티-2의 검색 결과가 하나가 아니거나 없습니다.
# 이촌동 미주A의 정보 담기를 3번까지 완료하였습니다.
# 이태원동 남산힐레지던스의 정보 담기를 5번까지 완료하였습니다.
# 청파동3가 효창PALACEVILLE의 정보 담기를 5번까지 완료하였습니다.
# 한남동 윌쏘나슈트의 검색 결과가 하나가 아니거나 없습니다.
# 한남동 효성빌리지의 정보 담기를 6번까지 완료하였습니다.
# 효창동 용산케이씨씨스위첸의 검색 결과가 하나가 아니거나 없습니다.
# 효창동 효창아트빌2차의 정보 담기를 6번까지 완료하였습니다.
# 후암동 신후암의 정보 담기를 7번까지 완료하였습니다.
# 갈현동 플라잉캐슬의 검색 결과가 하나가 아니거나 없습니다.
# 갈현동 힐튼의 정보 담기를 4번까지 완료하였습니다.
# 구산동 뉴월드빌의 정보 담기를 1번까지 완료하였습니다.
# 구산동 온세의 정보 담기를 1번까지 완료하였습니다.
# 구산동 이안의 정보 담기를 7번까지 완료하였습니다.
# 구산동 태영홈의 정보 담기를 3번까지 완료하였습니다.
# 녹번동 대신홈타운의 검색 결과가 하나가 아니거나 없습니다.
# 녹번동 초우레디안아트빌의 검색 결과가 하나가 아니거나 없습니다.
# 대조동 보성리엔빌의 검색 결과가 하나가 아니거나 없습니다.
# 불광동 금상의 정보 담기를 2번까지 완료하였습니다.
# 불광동 은혜스카이빌의 정보 담기를 7번까지 완료하였습니다.
# 불광동 해피플러스1의 정보 담기를 2번까지 완료하였습니다.
# 신사동 개성하이뷰의 정보 담기를 2번까지 완료하였습니다.
# 신사동 신현의 정보 담기를 3번까지 완료하였습니다.
# 신사동 우공101동의 정보 담기를 7번까지 완료하였습니다.
# 신사동 유성의 정보 담기를 3번까지 완료하였습니다.
# 신사동 테마빌2의 검색 결과가 하나가 아니거나 없습니다.
# 역촌동 귀빈의 정보 담기를 3번까지 완료하였습니다.
# 역촌동 디케이의 정보 담기를 6번까지 완료하였습니다.
# 역촌동 역촌의 검색 결과가 하나가 아니거나 없습니다.
# 역촌동 진주하이츠2차의 정보 담기를 1번까지 완료하였습니다.
# 응암동 명남래희안의 정보 담기를 2번까지 완료하였습니다.
# 응암동 엘엔씨레반트의 정보 담기를 6번까지 완료하였습니다.
# 부암동 부암스카이뷰의 정보 담기를 3번까지 완료하였습니다.
# 부암동 프라임캐슬의 검색 결과가 하나가 아니거나 없습니다.
# 숭인동 도시그린빌라의 검색 결과가 하나가 아니거나 없습니다.
# 숭인동 동문A의 검색 결과가 하나가 아니거나 없습니다.
# 숭인동 숭인모범102동의 검색 결과가 하나가 아니거나 없습니다.
# 원남동 하이텍하우스의 검색 결과가 하나가 아니거나 없습니다.
# 창신동 일우의 정보 담기를 1번까지 완료하였습니다.
# 통인동 효자의 정보 담기를 7번까지 완료하였습니다.
# 신당동 토토타워의 정보 담기를 5번까지 완료하였습니다.
# 정동 정동의 검색 결과가 하나가 아니거나 없습니다.
# 충무로5가 이지마루충무로의 검색 결과가 하나가 아니거나 없습니다.
# 황학동 위너빌의 검색 결과가 하나가 아니거나 없습니다.
# 황학동 청계리버팰리스B의 검색 결과가 하나가 아니거나 없습니다.
# 망우동 세움삼익플라주의 정보 담기를 4번까지 완료하였습니다.
# 망우동 월드101의 검색 결과가 하나가 아니거나 없습니다.
# 망우동 월드102의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 유진뜨레지움의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 해동훼미리의 정보 담기를 3번까지 완료하였습니다.
# 논현동 마블하우스의 정보 담기를 2번까지 완료하였습니다.
# 논현동 세호시티라이프의 정보 담기를 6번까지 완료하였습니다.
# 논현동 힐스빌7의 정보 담기를 5번까지 완료하였습니다.
# 논현동 힐타워의 정보 담기를 7번까지 완료하였습니다.
# 대치동 대치타워의 검색 결과가 하나가 아니거나 없습니다.
# 대치동 삼환SOGOOD의 정보 담기를 2번까지 완료하였습니다.
# 대치동 스카이써밋의 정보 담기를 4번까지 완료하였습니다.
# 대치동 풍림아이원1차101동의 검색 결과가 하나가 아니거나 없습니다.
# 대치동 풍림아이원3차의 정보 담기를 2번까지 완료하였습니다.
# 삼성동 대우멤버스카운티201의 검색 결과가 하나가 아니거나 없습니다.
# 삼성동 삼성팰리스의 검색 결과가 하나가 아니거나 없습니다.
# 신사동 신사아이빌의 정보 담기를 5번까지 완료하였습니다.
# 신사동 신사파크빌B동의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 강남웅진베어스빌의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 경민리빙텔의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 로얄팰리스의 정보 담기를 7번까지 완료하였습니다.
# 역삼동 상지리츠빌역삼2차의 정보 담기를 6번까지 완료하였습니다.
# 역삼동 역삼동칼라의 정보 담기를 7번까지 완료하였습니다.
# 역삼동 역삼예명의 정보 담기를 4번까지 완료하였습니다.
# 일원동 호정빌라트의 정보 담기를 3번까지 완료하였습니다.
# 청담동 삼호빌라B동의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 상지리츠빌4B의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 연세힐하우스의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 이니그마빌2의 정보 담기를 7번까지 완료하였습니다.
# 청담동 청담대우멤버스카운티10차의 정보 담기를 6번까지 완료하였습니다.
# 청담동 청담파크빌의 검색 결과가 하나가 아니거나 없습니다.
# 길동 웅주아크로파크의 정보 담기를 7번까지 완료하였습니다.
# 길동 하이존의 정보 담기를 5번까지 완료하였습니다.
# 길동 해맞이비동의 검색 결과가 하나가 아니거나 없습니다.
# 명일동 세비앙의 검색 결과가 하나가 아니거나 없습니다.
# 성내동 성내동AURAⅡ의 정보 담기를 2번까지 완료하였습니다.
# 성내동 성내웰빙시티의 정보 담기를 7번까지 완료하였습니다.
# 성내동 운암화인빌102의 정보 담기를 3번까지 완료하였습니다.
# 성내동 집앤사비키의 정보 담기를 7번까지 완료하였습니다.
# 성내동 한솔애리즈의 검색 결과가 하나가 아니거나 없습니다.
# 성내동 한솔애리즈202동의 검색 결과가 하나가 아니거나 없습니다.
# 성내동 현대상가의 검색 결과가 하나가 아니거나 없습니다.
# 암사동 한양그린의 정보 담기를 7번까지 완료하였습니다.
# 천호동 리버하임의 정보 담기를 6번까지 완료하였습니다.
# 천호동 새롬트윈스의 정보 담기를 3번까지 완료하였습니다.
# 천호동 아크로파크의 정보 담기를 6번까지 완료하였습니다.
# 천호동 지원G델타의 정보 담기를 1번까지 완료하였습니다.
# 미아동 두예파크빌의 정보 담기를 6번까지 완료하였습니다.
# 내발산동 내츄럴1차의 정보 담기를 7번까지 완료하였습니다.
# 내발산동 새신아의 정보 담기를 5번까지 완료하였습니다.
# 내발산동 신세계4차의 정보 담기를 1번까지 완료하였습니다.
# 화곡동 곰달래의 정보 담기를 4번까지 완료하였습니다.
# 화곡동 대성3,4호의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 우공팰리스101동의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 우공팰리스102동의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 은창의 정보 담기를 4번까지 완료하였습니다.
# 화곡동 진민그린상가의 정보 담기를 3번까지 완료하였습니다.
# 화곡동 탑건화곡동진선미의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 투원씨B동의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 호성그린아트빌의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 화곡대진의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 화곡동성재의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 화성파크빌의 검색 결과가 하나가 아니거나 없습니다.
# 남현동 기아하이츠빌의 정보 담기를 3번까지 완료하였습니다.
# 남현동 성원나이스의 정보 담기를 6번까지 완료하였습니다.
# 남현동 세종하이츠의 정보 담기를 5번까지 완료하였습니다.
# 남현동 쎈트앤빌의 검색 결과가 하나가 아니거나 없습니다.
# 남현동 진영씨티파크APT의 정보 담기를 3번까지 완료하였습니다.
# 봉천동 낙성대늘푸른의 검색 결과가 하나가 아니거나 없습니다.
# 봉천동 새진5차의 검색 결과가 하나가 아니거나 없습니다.
# 봉천동 은선의 검색 결과가 하나가 아니거나 없습니다.
# 봉천동 은선파인빌의 정보 담기를 7번까지 완료하였습니다.
# 봉천동 코스코수의 정보 담기를 3번까지 완료하였습니다.
# 봉천동 태승의 정보 담기를 7번까지 완료하였습니다.
# 신림동 고흥의 정보 담기를 1번까지 완료하였습니다.
# 구의동 강변힐하우스의 검색 결과가 하나가 아니거나 없습니다.
# 구의동 그레이스홈타운의 검색 결과가 하나가 아니거나 없습니다.
# 구의동 나크빌라트의 정보 담기를 2번까지 완료하였습니다.
# 구의동 청목파크빌의 검색 결과가 하나가 아니거나 없습니다.
# 구의동 해성의 정보 담기를 7번까지 완료하였습니다.
# 자양동 기산빌라트의 정보 담기를 3번까지 완료하였습니다.
# 중곡동 대영1동의 검색 결과가 하나가 아니거나 없습니다.
# 개봉동 레오의 정보 담기를 5번까지 완료하였습니다.
# 개봉동 천신하이츠의 정보 담기를 5번까지 완료하였습니다.
# 고척동 해피그린의 정보 담기를 7번까지 완료하였습니다.
# 구로동 삼성빌라트의 정보 담기를 1번까지 완료하였습니다.
# 구로동 경원주택의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 가람빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 동화의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 명성빌라3차의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 성산E동의 검색 결과가 하나가 아니거나 없습니다.
# 궁동 호수2차B동의 검색 결과가 하나가 아니거나 없습니다.
# 오류동 비에이치수반애수목원의 정보 담기를 7번까지 완료하였습니다.
# 독산동 리치힐103동의 정보 담기를 5번까지 완료하였습니다.
# 독산동 상진지오벨리B의 정보 담기를 5번까지 완료하였습니다.
# 시흥동 루체클래식의 정보 담기를 7번까지 완료하였습니다.
# 시흥동 삼일의 정보 담기를 4번까지 완료하였습니다.
# 시흥동 신동힐탑의 정보 담기를 2번까지 완료하였습니다.
# 시흥동 웨스트밸리의 검색 결과가 하나가 아니거나 없습니다.
# 공릉동 서로퍼스트빌의 정보 담기를 4번까지 완료하였습니다.
# 공릉동 주완위즈빌2의 정보 담기를 5번까지 완료하였습니다.
# 공릉동 플라체76의 정보 담기를 7번까지 완료하였습니다.
# 상계동 센트럴의 검색 결과가 하나가 아니거나 없습니다.
# 중계동 부강쉘브르의 정보 담기를 3번까지 완료하였습니다.
# 쌍문동 벽산송화프라자의 정보 담기를 3번까지 완료하였습니다.
# 창동 금강101의 정보 담기를 7번까지 완료하였습니다.
# 창동 창동역블루핀1동의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 NS파크타운의 정보 담기를 6번까지 완료하였습니다.
# 장안동 월튼파크뷰2차의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 장안SM드림빌의 정보 담기를 2번까지 완료하였습니다.
# 장안동 천강의 정보 담기를 7번까지 완료하였습니다.
# 장안동 현대리노빌101동의 정보 담기를 7번까지 완료하였습니다.
# 대방동 대방홈타운의 검색 결과가 하나가 아니거나 없습니다.
# 상도1동 정호탑의 정보 담기를 7번까지 완료하였습니다.
# 상도동 세레노의 정보 담기를 7번까지 완료하였습니다.
# 상도동 한강리버힐B동의 검색 결과가 하나가 아니거나 없습니다.
# 공덕동 공덕스카이의 정보 담기를 1번까지 완료하였습니다.
# 공덕동 공덕헤리지움의 검색 결과가 하나가 아니거나 없습니다.
# 도화동 현대예술의 정보 담기를 4번까지 완료하였습니다.
# 동교동 광남벨라스2동의 정보 담기를 7번까지 완료하였습니다.
# 망원동 길명2차의 정보 담기를 3번까지 완료하였습니다.
# 성산동 해피존의 검색 결과가 하나가 아니거나 없습니다.
# 합정동 그레이스3차의 정보 담기를 3번까지 완료하였습니다.
# 북가좌동 동도하이츠에이동의 검색 결과가 하나가 아니거나 없습니다.
# 홍은동 나영힐빌리지의 검색 결과가 하나가 아니거나 없습니다.
# 홍은동 넥서스빌2의 정보 담기를 2번까지 완료하였습니다.
# 홍은동 신원지벤스타2의 정보 담기를 6번까지 완료하였습니다.
# 홍은동 신원지벤스타7의 검색 결과가 하나가 아니거나 없습니다.
# 반포동 그린피아의 정보 담기를 2번까지 완료하였습니다.
# 반포동 다우탑스빌라트의 정보 담기를 7번까지 완료하였습니다.
# 반포동 반포샤인힐4차의 정보 담기를 4번까지 완료하였습니다.
# 반포동 신구노빌리티의 정보 담기를 5번까지 완료하였습니다.
# 반포동 장원빌라트의 정보 담기를 4번까지 완료하였습니다.
# 반포동 테마하우스의 정보 담기를 7번까지 완료하였습니다.
# 방배동 골드아트빌의 정보 담기를 5번까지 완료하였습니다.
# 방배동 나스빌3차의 정보 담기를 7번까지 완료하였습니다.
# 방배동 다움7샤인힐의 정보 담기를 5번까지 완료하였습니다.
# 방배동 모닝아트빌의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 방배노블힐스의 정보 담기를 4번까지 완료하였습니다.
# 방배동 방배대우멤버스카운티201의 정보 담기를 2번까지 완료하였습니다.
# 방배동 방배대우멤버스카운티502의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 방배아트e-편한세상106의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 방배포레스트의 정보 담기를 1번까지 완료하였습니다.
# 방배동 베로니스3차의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 스톤힐스의 정보 담기를 7번까지 완료하였습니다.
# 방배동 정림의 정보 담기를 7번까지 완료하였습니다.
# 방배동 카사벨라의 검색 결과가 하나가 아니거나 없습니다.
# 방배동 탑빌라트의 정보 담기를 2번까지 완료하였습니다.
# 서초동 N-Suite102동의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 다우월드의 정보 담기를 5번까지 완료하였습니다.
# 서초동 동아빌라트1의 정보 담기를 3번까지 완료하였습니다.
# 서초동 브라운스톤로얄스위트서초의 정보 담기를 5번까지 완료하였습니다.
# 서초동 비버리캐슬의 정보 담기를 4번까지 완료하였습니다.
# 서초동 서초동아의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 서초타워시티빌의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 신구블레스벨리의 정보 담기를 3번까지 완료하였습니다.
# 서초동 월드메르디앙B의 검색 결과가 하나가 아니거나 없습니다.
# 서초동 장복엘리트타운의 정보 담기를 5번까지 완료하였습니다.
# 양재동 금일의 정보 담기를 6번까지 완료하였습니다.
# 양재동 드림팰리스103동의 검색 결과가 하나가 아니거나 없습니다.
# 양재동 리시본하우스의 정보 담기를 7번까지 완료하였습니다.
# 양재동 우면파크의 정보 담기를 6번까지 완료하였습니다.
# 양재동 해청의 검색 결과가 하나가 아니거나 없습니다.
# 잠원동 현대실크빌의 정보 담기를 1번까지 완료하였습니다.
# 마장동 아트리움의 정보 담기를 7번까지 완료하였습니다.
# 동소문동4가 양지의 정보 담기를 7번까지 완료하였습니다.
# 보문동6가 동문골드빌B동의 검색 결과가 하나가 아니거나 없습니다.
# 정릉동 미양산타빌의 정보 담기를 4번까지 완료하였습니다.
# 가락동 로즈힐파크의 정보 담기를 7번까지 완료하였습니다.
# 가락동 정산파크뷰의 정보 담기를 7번까지 완료하였습니다.
# 가락동 주성드림의 검색 결과가 하나가 아니거나 없습니다.
# 마천동 보보스빌의 정보 담기를 2번까지 완료하였습니다.
# 방이동 대양코리아나타워의 정보 담기를 4번까지 완료하였습니다.
# 방이동 인텍스빌의 검색 결과가 하나가 아니거나 없습니다.
# 방이동 한성나이스빌의 정보 담기를 1번까지 완료하였습니다.
# 석촌동 다성리치빌의 정보 담기를 4번까지 완료하였습니다.
# 석촌동 밀란체1의 검색 결과가 하나가 아니거나 없습니다.
# 석촌동 원남의 검색 결과가 하나가 아니거나 없습니다.
# 오금동 금성리치몬드의 정보 담기를 7번까지 완료하였습니다.
# 오금동 리오파크빌의 검색 결과가 하나가 아니거나 없습니다.
# 오금동 미소의 정보 담기를 2번까지 완료하였습니다.
# 오금동 혜성공원의 정보 담기를 7번까지 완료하였습니다.
# 목동 두란의 정보 담기를 7번까지 완료하였습니다.
# 목동 왕자상가의 검색 결과가 하나가 아니거나 없습니다.
# 목동 청포도의 정보 담기를 5번까지 완료하였습니다.
# 신월동 삼동5의 정보 담기를 2번까지 완료하였습니다.
# 신월동 이형원앙의 정보 담기를 2번까지 완료하였습니다.
# 신월동 호성파크1의 검색 결과가 하나가 아니거나 없습니다.
# 신정동 동국화이트빌A동의 정보 담기를 1번까지 완료하였습니다.
# 신정동 지오프레저102동의 검색 결과가 하나가 아니거나 없습니다.
# 대림동 다청림1동의 정보 담기를 7번까지 완료하였습니다.
# 신길동 제일골드타워의 정보 담기를 1번까지 완료하였습니다.
# 동빙고동 현대플래티앙1의 정보 담기를 4번까지 완료하였습니다.
# 한남동 한남동UNVILLAGE루하우스의 검색 결과가 하나가 아니거나 없습니다.
# 후암동 힐튼빌리지1차의 정보 담기를 4번까지 완료하였습니다.
# 갈현동 골드스타의 정보 담기를 4번까지 완료하였습니다.
# 갈현동 반도하우드의 정보 담기를 5번까지 완료하였습니다.
# 구산동 두일의 정보 담기를 2번까지 완료하였습니다.
# 녹번동 송학파크팰리스의 정보 담기를 2번까지 완료하였습니다.
# 녹번동 시니어캐슬클라시온의 검색 결과가 하나가 아니거나 없습니다.
# 녹번동 현재맨션의 정보 담기를 4번까지 완료하였습니다.
# 대조동 대덕타워의 정보 담기를 4번까지 완료하였습니다.
# 대조동 만민하늘愛의 검색 결과가 하나가 아니거나 없습니다.
# 대조동 정은노블스의 정보 담기를 1번까지 완료하였습니다.
# 불광동 남양구르미의 정보 담기를 6번까지 완료하였습니다.
# 신사동 다원그린의 정보 담기를 2번까지 완료하였습니다.
# 신사동 정은노블스A의 검색 결과가 하나가 아니거나 없습니다.
# 신사동 회림의 정보 담기를 3번까지 완료하였습니다.
# 역촌동 태경맨션의 검색 결과가 하나가 아니거나 없습니다.
# 무악동 무악다온채의 정보 담기를 5번까지 완료하였습니다.
# 부암동 별빛고운의 정보 담기를 7번까지 완료하였습니다.
# 숭인동 하림빌라트의 검색 결과가 하나가 아니거나 없습니다.
# 남산동2가 남산퍼시픽의 정보 담기를 7번까지 완료하였습니다.
# 만리동1가 SY파크힐의 정보 담기를 4번까지 완료하였습니다.
# 신당동 벨레어카운티의 검색 결과가 하나가 아니거나 없습니다.
# 오장동 정석그라시아의 검색 결과가 하나가 아니거나 없습니다.
# 면목동 글로벌파크의 정보 담기를 3번까지 완료하였습니다.
# 면목동 승일카이저의 정보 담기를 7번까지 완료하였습니다.
# 면목동 영우의 정보 담기를 6번까지 완료하였습니다.
# 면목동 킴스타워의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 매원의 정보 담기를 7번까지 완료하였습니다.
# 상봉동 솔렌시아5의 검색 결과가 하나가 아니거나 없습니다.
# 상봉동 청운명가프라임의 검색 결과가 하나가 아니거나 없습니다.
# 신내동 월드크라운의 정보 담기를 7번까지 완료하였습니다.
# 중화동 남광타운의 정보 담기를 2번까지 완료하였습니다.
# 개포동 개포현대6차의 정보 담기를 7번까지 완료하였습니다.
# 논현동 논현인텔의 정보 담기를 6번까지 완료하였습니다.
# 도곡동 도곡현대힐스테이트101동의 검색 결과가 하나가 아니거나 없습니다.
# 도곡동 이니그마빌-III의 검색 결과가 하나가 아니거나 없습니다.
# 삼성동 상아빌라트의 정보 담기를 7번까지 완료하였습니다.
# 압구정동 현대65동의 정보 담기를 4번까지 완료하였습니다.
# 역삼동 뉴엠빌라트의 검색 결과가 하나가 아니거나 없습니다.
# 역삼동 예지인의 정보 담기를 7번까지 완료하였습니다.
# 역삼동 탑팰리스의 정보 담기를 4번까지 완료하였습니다.
# 역삼동 프리우스역삼101동의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 뉴현대리버빌의 정보 담기를 5번까지 완료하였습니다.
# 청담동 연세리버테라스의 정보 담기를 4번까지 완료하였습니다.
# 청담동 청담7상지리츠빌의 검색 결과가 하나가 아니거나 없습니다.
# 청담동 청담대우멤버스카운티9차의 정보 담기를 4번까지 완료하였습니다.
# 길동 다성팰리스의 정보 담기를 7번까지 완료하였습니다.
# 성내동 성주아트빌의 검색 결과가 하나가 아니거나 없습니다.
# 내발산동 한서2차APT의 정보 담기를 3번까지 완료하였습니다.
# 방화동 양진마니아의 정보 담기를 7번까지 완료하였습니다.
# 방화동 통일102동의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 신원2차의 검색 결과가 하나가 아니거나 없습니다.
# 화곡동 팔라이스타워의 정보 담기를 4번까지 완료하였습니다.
# 남현동 뉴타운1동의 검색 결과가 하나가 아니거나 없습니다.
# 남현동 뉴타운B동의 정보 담기를 7번까지 완료하였습니다.
# 봉천동 신성새실마을102동의 검색 결과가 하나가 아니거나 없습니다.
# 봉천동 위너스이즈의 정보 담기를 7번까지 완료하였습니다.
# 봉천동 은천누리에뜰의 정보 담기를 2번까지 완료하였습니다.
# 봉천동 카후나빌의 정보 담기를 7번까지 완료하였습니다.
# 신림동 성지하우스의 검색 결과가 하나가 아니거나 없습니다.
# 구의동 아차산인앤인W클래스101동의 정보 담기를 7번까지 완료하였습니다.
# 자양동 대종리버빌의 정보 담기를 7번까지 완료하였습니다.
# 구로동 우진빌라1차B의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 문화아트빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 우리빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 삼주빌라의 검색 결과가 하나가 아니거나 없습니다.
# 구로동 에덴빌라의 검색 결과가 하나가 아니거나 없습니다.
# 궁동 선우쉐르빌의 검색 결과가 하나가 아니거나 없습니다.
# 시흥동 금천리메인시티의 검색 결과가 하나가 아니거나 없습니다.
# 공릉동 보람노블레스의 정보 담기를 6번까지 완료하였습니다.
# 상계동 불암신기102동의 검색 결과가 하나가 아니거나 없습니다.
# 장안동 광진아트빌12차의 정보 담기를 7번까지 완료하였습니다.
# 장안동 성진위드빌의 검색 결과가 하나가 아니거나 없습니다.

# %%
apt_info
# Out:
# 동아파트명       0
# 세대수      1371
# 저_최고층    1371
# 총주차대수    1371
# 용적률      1371
# 건폐율      1371
# 건설사      1371
# dtype: int64

# %%
apt_area
# Out:
# 동아파트명      0
# 공급전용면적     0
# 방수욕실수      0
# 해당면적세대수    0
# 현관구조       0
# dtype: int64

# %%
idx
# Out:
# [1,
#  2,
#  3,
#  5,
#  9,
#  14,
#  16,
#  17,
#  22,
#  23,
#  24,
#  30,
#  31,
#  33,
#  35,
#  36,
#  37,
#  40,
#  41,
#  42,
#  45,
#  46,
#  52,
#  60,
#  61,
#  62,
#  63,
#  66,
#  68,
#  72,
#  73,
#  84,
#  86,
#  91,
#  94,
#  95,
#  98,
#  101,
#  106,
#  109,
#  116,
#  122,
#  126,
#  127,
#  129,
#  130,
#  133,
#  135,
#  139,
#  140,
#  149,
#  159,
#  160,
#  161,
#  174,
#  176,
#  186,
#  187,
#  188,
#  192,
#  193,
#  199,
#  205,
#  206,
#  212,
#  215,
#  216,
#  221,
#  222,
#  225,
#  226,
#  231,
#  233,
#  235,
#  242,
#  244,
#  246,
#  248,
#  256,
#  257,
#  260,
#  261,
#  262,
#  263,
#  265,
#  266,
#  267,
#  271,
#  273,
#  276,
#  277,
#  278,
#  279,
#  282,
#  287,
#  288,
#  289,
#  291,
#  293,
#  294,
#  295,
#  296,
#  297,
#  298,
#  300,
#  310,
#  311,
#  312,
#  313,
#  315,
#  316,
#  319,
#  322,
#  347,
#  348,
#  351,
#  354,
#  355,
#  358,
#  359,
#  360,
#  361,
#  362,
#  363,
#  366,
#  381,
#  382,
#  391,
#  402,
#  403,
#  404,
#  407,
#  425,
#  430,
#  433,
#  439,
#  448,
#  451,
#  457,
#  458,
#  470,
#  471,
#  475,
#  477,
#  480,
#  484,
#  485,
#  488,
#  490,
#  491,
#  503,
#  506,
#  507,
#  511,
#  513,
#  515,
#  517,
#  518,
#  519,
#  520,
#  523,
#  524,
#  526,
#  539,
#  540,
#  541,
#  542,
#  545,
#  546,
#  547,
#  549,
#  550,
#  551,
#  553,
#  554,
#  556,
#  557,
#  560,
#  573,
#  575,
#  577,
#  579,
#  582,
#  584,
#  586,
#  588,
#  592,
#  594,
#  595,
#  599,
#  601,
#  602,
#  603,
#  604,
#  606,
#  609,
#  611,
#  614,
#  621,
#  622,
#  623,
#  624,
#  625,
#  627,
#  629,
#  630,
#  639,
#  640,
#  643,
#  645,
#  648,
#  649,
#  652,
#  654,
#  658,
#  660,
#  663,
#  664,
#  666,
#  667,
#  668,
#  669,
#  671,
#  672,
#  677,
#  680,
#  684,
#  693,
#  697,
#  701,
#  706,
#  708,
#  709,
#  711,
#  712,
#  713,
#  714,
#  715,
#  717,
#  719,
#  720,
#  725,
#  726,
#  727,
#  728,
#  730,
#  735,
#  738,
#  740,
#  749,
#  750,
#  756,
#  757,
#  758,
#  759,
#  760,
#  761,
#  762,
#  763,
#  764,
#  765,
#  767,
#  769,
#  770,
#  771,
#  773,
#  775,
#  776,
#  783,
#  785,
#  786,
#  790,
#  791,
#  792,
#  793,
#  794,
#  796,
#  797,
#  800,
#  805,
#  806,
#  807,
#  808,
#  814,
#  815,
#  818,
#  826,
#  829,
#  835,
#  840,
#  843,
#  845,
#  858,
#  860,
#  863,
#  864,
#  870,
#  874,
#  875,
#  876,
#  879,
#  890,
#  892,
#  893,
#  894,
#  896,
#  897,
#  898,
#  902,
#  903,
#  909,
#  912,
#  915,
#  916,
#  919,
#  921,
#  923,
#  927,
#  928,
#  929,
#  930,
#  931,
#  933,
#  936,
#  937,
#  938,
#  939,
#  940,
#  941,
#  942,
#  949,
#  954,
#  961,
#  962,
#  963,
#  967,
#  969,
#  978,
#  979,
#  980,
#  982,
#  987,
#  997,
#  998,
#  1001,
#  1003,
#  1008,
#  1010,
#  1020,
#  1021,
#  1024,
#  1028,
#  1030,
#  1031,
#  1032,
#  1036,
#  1039,
#  1041,
#  1044,
#  1045,
#  1046,
#  1047,
#  1048,
#  1049,
#  1050,
#  1051,
#  1052,
#  1053,
#  1054,
#  1055,
#  1056,
#  1057,
#  1058,
#  1059,
#  1060,
#  1061,
#  1062,
#  1063,
#  1064,
#  1065,
#  1066,
#  1067,
#  1068,
#  1069,
#  1070,
#  1071,
#  1072,
#  1075,
#  1078,
#  1079,
#  1080,
#  1082,
#  1083,
#  1084,
#  1090,
#  1092,
#  1104,
#  1106,
#  1107,
#  1109,
#  1112,
#  1116,
#  1117,
#  1120,
#  1121,
#  1122,
#  1123,
#  1124,
#  1125,
#  1131,
#  1133,
#  1148,
#  1152,
#  1153,
#  1154,
#  1155,
#  1156,
#  1157,
#  1160,
#  1164,
#  1166,
#  1167,
#  1171,
#  1172,
#  1175,
#  1181,
#  1185,
#  1188,
#  1194,
#  1195,
#  1200,
#  1205,
#  1206,
#  1208,
#  1210,
#  1212,
#  1214,
#  1216,
#  1218,
#  1219,
#  1225,
#  1233,
#  1240,
#  1241,
#  1246,
#  1248,
#  1249,
#  1254,
#  1258,
#  1259,
#  1265,
#  1266,
#  1269,
#  1272,
#  1276,
#  1278,
#  1282,
#  1284,
#  1287,
#  1293,
#  1294,
#  1295,
#  1303,
#  1306,
#  1311,
#  1312,
#  1313,
#  1314,
#  1315,
#  1319,
#  1320,
#  1321,
#  1322,
#  1324,
#  1325,
#  1326,
#  1332,
#  1335,
#  1337,
#  1338,
#  1340,
#  1341,
#  1342,
#  1348,
#  1349,
#  1350,
#  1353,
#  1356,
#  1357,
#  1362,
#  1363,
#  1364,
#  1375,
#  1376,
#  1377,
#  1380,
#  1381,
#  1382,
#  1383,
#  1384,
#  1385,
#  1389,
#  1391,
#  1392,
#  1393,
#  1398,
#  1399,
#  1401,
#  1404,
#  1409,
#  1410,
#  1411,
#  1412,
#  1413,
#  1414,
#  1421,
#  1425,
#  1429,
#  1431,
#  1435,
#  1438,
#  1440,
#  1444,
#  1446,
#  1447,
#  1450,
#  1460,
#  1463,
#  1464,
#  1466,
#  1469,
#  1471,
#  1476,
#  1477,
#  1479,
#  1482,
#  1485,
#  1489,
#  1493,
#  1497,
#  1500,
#  1501,
#  1503,
#  1507,
#  1511,
#  1513,
#  1518,
#  1524,
#  1527,
#  1531,
#  1533,
#  1536,
#  1539,
#  1540,
#  1544,
#  1546,
#  1547,
#  1552,
#  1553,
#  1556,
#  1559,
#  1562,
#  1565,
#  1568,
#  1569,
#  1571,
#  1573,
#  1577,
#  1580,
#  1581,
#  1582,
#  1583,
#  1584,
#  1585,
#  1586,
#  1588,
#  1590]

# %%
# 저장
apt_info.to_csv('../Data/아파트정보.csv', index = False)
apt_area.to_csv('../Data/아파트면적정보.csv', index = False)
